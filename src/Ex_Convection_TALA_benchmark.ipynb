# %% [markdown]
# # King Benchmark Case 1
#
# ## Isoviscous thermal convection with TALA formulation.
#
# Two-dimensional, compressible, bottom heated, steady isoviscous thermal convection in a 1 x 1 box, see case 1 of [King et al. (2009)](https://doi.org/10.1111/j.1365-246X.2009.04413.x) / [Blankenbach et al. (1989) benchmark](https://academic.oup.com/gji/article/98/1/23/622167).
#
# Keywords: Truncated Anelastic Liquid Approximation, TALA, Convection

# %%
import petsc4py
from petsc4py import PETSc

import underworld3 as uw
from underworld3.systems import Stokes
from underworld3 import function

import os 
import numpy as np
import sympy
from sympy.vector import gradient, divergence, dot

# %% [markdown]
# ### Set parameters to use

# %%
Di = 0.5 # dissipation factor - FIXME: in terms of the physical parameters or do some checks on the physical meanings
Ra = 1e4 #### Rayleigh number

# other non-dimensional parameters
gamma_r = 1.    # reference Gruneisen parameter TODO: set-up to correct values
alpha_bar = 1   # this is set to 1 in the paper 
c_p = 1         # set to 1 for now
T_s = 0.091     # non-dimensionalized surface temp (TODO: 273 K/3000 K as per Davies et al)
rho_0  = 1      # non-dimensionalized surface density (TODO: set-up to correct value)

k = 1.0 #### diffusivity

boxLength = 1.0
boxHeight = 1.0
tempMin   = 0.
tempMax   = 1.
deltaTemp = tempMax - tempMin

viscosity = 1

res= 16             ### x and y res of box
nsteps = 100        ### maximum number of time steps to run the first model 
epsilon_lr = 1e-8   ### criteria for early stopping; relative change of the Vrms in between iterations

# %% [markdown]
# ### Create mesh and variables

# %%
meshbox = uw.meshing.UnstructuredSimplexBox(
                                                minCoords=(0.0, 0.0), 
                                                maxCoords=(boxLength, boxHeight), 
                                                cellSize=1.0 /res, 
                                                regular=False, 
                                                qdegree = 3
                                        )

#meshbox = uw.meshing.StructuredQuadBox(minCoords=(0.0, 0.0), maxCoords=(boxLength, boxHeight),  elementRes=(res,res))

# the reference curves are prepared here
# we follow the reference and set z = 0 to be the upper surface and z = 1 to be the lower surface
# this means that z = 0 is set at total temperature of 0 while z = 1 is set to total temp = 1
# we just need to reverse this during plotting
# Out:
# Processing gmsh file .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh
# Mesh saved to .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh.h5

# %% [markdown]
# ## Reference values
# The temperature, T, pressure, p, and density are expressed as a sum of a reference state and a departure from this state:
#
# \begin{aligned}
# T = \bar T + T'\space \; \; \; p = \bar p + p'  \; \; \;  \rho = \bar \rho (\bar T, \bar p) + \rho'
# \end{aligned}
#
# Where the overbarred quantities are the reference states, and the primed quantities are the perturbations. The reference states are temporally static and varies with depth, z.

# %%
# the non-dimensionalized reference states are defined here
# formulations from King et al. and Davies et al.  
x, z = meshbox.X
rho_bar     = rho_0*sympy.exp(Di*z/gamma_r)         # rho_0 is non-dimensionalized density at surface TODO: double check this
temp_bar    = T_s*(sympy.exp(Di*z) - 1)            # T_s is non-dimensionalized surface temperature

# %%
# visualise the mesh if in a notebook / serial

if uw.mpi.size == 1:
    import numpy as np
    import pyvista as pv
    import vtk

    pv.global_theme.background = "white"
    pv.global_theme.window_size = [750, 750]
    pv.global_theme.antialiasing = True
    pv.global_theme.jupyter_backend = "panel"
    pv.global_theme.smooth_shading = True
    pv.global_theme.camera["viewup"] = [0.0, 1.0, 0.0]
    pv.global_theme.camera["position"] = [0.0, 0.0, -5.0]
    pv.global_theme.show_edges = True
    pv.global_theme.axes.show = True

    meshbox.vtk("tmp_box_mesh.vtk")
    pvmesh = pv.read("tmp_box_mesh.vtk")
    pl = pv.Plotter()

    # pl.add_mesh(pvmesh,'Black', 'wireframe', opacity=0.5)
    pl.add_mesh(pvmesh, edge_color="Black", show_edges=True)

    pl.show(cpos="xy")
# Out:
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2500: PyVistaDeprecationWarning: antialising is deprecated.  Please use `anti_aliasing` instead.
#   warnings.warn(
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2468: PyVistaDeprecationWarning: `anti_aliasing` is now a string or None and must be either "ssaa", "msaa", "fxaa", or None
#   warnings.warn(
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# /var/folders/91/xdyy27357hv1tymzym7xhf5h0000gq/T/ipykernel_40701/1359165157.py:11: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.global_theme.jupyter_backend = "panel"
# BokehModel(combine_events=True, render_bundle={'docs_json': {'dbf92729-ded2-4d2c-a374-d768b6ea93df': {'defs': …

# %%
v_soln = uw.discretisation.MeshVariable("U", meshbox, meshbox.dim, degree=2)
p_soln = uw.discretisation.MeshVariable("P", meshbox, 1, degree=1)
t_soln = uw.discretisation.MeshVariable("T", meshbox, 1, degree=3)
t_0 = uw.discretisation.MeshVariable("T0", meshbox, 1, degree=3)

# additional variable for the gradient
dTdZ = uw.discretisation.MeshVariable(r"\partial T/ \partial \Z", # FIXME: Z should not be a function of x, y, z 
                                      meshbox, 
                                      1, 
                                      degree = 3) 

# variable containing stress in the z direction
sigma_zz = uw.discretisation.MeshVariable(r"\sigma_{zz}",  
                                        meshbox, 
                                        1, degree=2)


# ### some projection objects to calculate the
# x, y = meshbox.X

# t_soln_grad = uw.systems.Projection(meshbox, dTdZ)
# delT = t_soln.sym.diff(y)[0]
# t_soln_grad.uw_function = delT
# t_soln_grad.smoothing = 1.0e-3
# t_soln_grad.petsc_options.delValue("ksp_monitor")
# Out:
# Variable with name U already exists on the mesh - Skipping.
# Variable with name P already exists on the mesh - Skipping.
# Variable with name T already exists on the mesh - Skipping.
# Variable with name T0 already exists on the mesh - Skipping.
# Variable with name \partial T/ \partial \Z already exists on the mesh - Skipping.
# Variable with name \sigma_{zz} already exists on the mesh - Skipping.

# %% [markdown]
# ### System set-up (Stokes)
# In the Truncated Anelastic Liquid Approximation, the conservation of mass is expressed as:
# \begin{aligned}
# \nabla \cdot (\bar \rho \vec u) = \nabla \cdot \vec u + \frac{1}{\bar \rho} \vec u \nabla \bar \rho = 0.
# \end{aligned}
# While the conservation of momentum is given as:
# \begin{aligned}
# \nabla \cdot [\eta (\nabla \vec u + \nabla \vec u^T - \frac {2}{3}\nabla \cdot \vec u \bold I)] - \nabla p' - Ra \bar \rho \bar g \bar \alpha (T - \bar T)= 0.
# \end{aligned}
# The deviatoric strain tensor, $\tau$, is:
# \begin{aligned}
# \tau = 2 \eta \dot \epsilon = \eta (\nabla \vec u + \nabla \vec u^T - \frac {2}{3}\nabla \cdot \vec u \bold I)
# \end{aligned}

# %%
# Create Stokes object

stokes = Stokes(
    meshbox,
    velocityField=v_soln,
    pressureField=p_soln,
    solver_name="stokes",
)

# stokes petsc parameters
# stokes.petsc_options["ksp_monitor"] = None
# stokes.petsc_options['pc_type'] = 'lu'
# stokes.petsc_options["snes_max_it"] = 1000

# stokes.petsc_options["snes_atol"] = 1e-6
# stokes.petsc_options["snes_rtol"] = 1e-6


#stokes.petsc_options["ksp_rtol"]  = 1e-5 # reduce tolerance to increase speed

# Set solve options here (or remove default values
# stokes.petsc_options.getAll()

#stokes.petsc_options["snes_rtol"] = 1.0e-6
# stokes.petsc_options["fieldsplit_pressure_ksp_monitor"] = None
# stokes.petsc_options["fieldsplit_velocity_ksp_monitor"] = None
# stokes.petsc_options["fieldsplit_pressure_ksp_rtol"] = 1.0e-6
# stokes.petsc_options["fieldsplit_velocity_ksp_rtol"] = 1.0e-2
# stokes.petsc_options.delValue("pc_use_amat")

# additional term in constitutive equation? 
stokes.constitutive_model = uw.systems.constitutive_models.ViscousFlowModel(meshbox.dim)
stokes.constitutive_model.Parameters.viscosity=viscosity
# stokes.saddle_preconditioner = 1.0 / viscosity
# TODO: constitutive equation

# Free-slip boundary conditions
stokes.add_dirichlet_bc((0.0,), "Left", (0,))
stokes.add_dirichlet_bc((0.0,), "Right", (0,))
stokes.add_dirichlet_bc((0.0,), "Top", (1,))
stokes.add_dirichlet_bc((0.0,), "Bottom", (1,))

buoyancy_force = -Ra * rho_bar * alpha_bar * (t_soln.sym[0] - temp_bar) # directed downwards toward z = 0 (surface)
stokes.bodyforce = sympy.Matrix([0, buoyancy_force])

# add terms into the conservation of mass according to the formulation in King et al 
stokes.PF0 = sympy.Matrix([dot(v_soln.fn, gradient(rho_bar))/rho_bar])

stokes.stokes_problem_description() # FIXME: need to run this?

# %%
stokes._Einv2
# Out:
# sqrt(U_{ 0,0}(N0.x, N0.y)**2/2 + U_{ 0,1}(N0.x, N0.y)**2/4 + U_{ 0,1}(N0.x, N0.y)*U_{ 1,0}(N0.x, N0.y)/2 + U_{ 1,0}(N0.x, N0.y)**2/4 + U_{ 1,1}(N0.x, N0.y)**2/2)

# %%
# check the equations for the Stokes system
display(stokes._p_f0) # LHS of c.o. mass 
display(stokes._u_f1) # LHS of c.o. momentum
display(stokes._u_f0) # RHS of c.o. momentum / buoyancy force
# Out:
# Matrix([[U_{ 0,0}(N0.x, N0.y) + 0.5*U_{ 1 }(N0.x, N0.y) + U_{ 1,1}(N0.x, N0.y)]])
# Matrix([
# [    -P(N0.x, N0.y) + 2*U_{ 0,0}(N0.x, N0.y), U_{ 0,1}(N0.x, N0.y) + U_{ 1,0}(N0.x, N0.y)],
# [U_{ 0,1}(N0.x, N0.y) + U_{ 1,0}(N0.x, N0.y),     -P(N0.x, N0.y) + 2*U_{ 1,1}(N0.x, N0.y)]])
# Matrix([[0, 10000.0*(T(N0.x, N0.y) - 0.091*exp(0.5*N0.y) + 0.091)*exp(0.5*N0.y)]])

# %% [markdown]
# ### System set-up (Advection-Diffusion)
# In the TALA formulation, the conservation of energy in terms of the total temperature, T, is expressed as:
#
# \begin{aligned}
# \frac{DT}{Dt} - \frac{Di \bar \alpha}{\bar c_p}\vec g \cdot \vec u (T + T_s) = \frac {1} {\bar \rho \bar c_p} \nabla \cdot (\bar k \nabla T) + \frac{Di}{Ra} \frac{1}{\bar \rho \bar c_p} \phi
# \end{aligned}

# %%
# Create adv_diff object

adv_diff = uw.systems.AdvDiffusionSLCN(
    meshbox,
    u_Field=t_soln,
    V_Field=v_soln,
    solver_name="adv_diff",
)

adv_diff.constitutive_model = uw.systems.constitutive_models.DiffusionModel(meshbox.dim)
adv_diff.constitutive_model.Parameters.diffusivity = (k/(rho_bar*c_p))

# add source terms based needed for the EBA case - sympy expressions
#term1 = (Di/Ra)*2*viscosity*2*(stokes._Einv2**2)*(1/(rho_bar*c_p)) # FIXME: change to account for different constitutive equation, change Einv2
#term2 = (Di*alpha_bar/c_p)*v_soln.sym[1]*(t_soln.sym[0] + T_s) # FIXME: change the variable names
#term3 = (Di**2/(rho_bar*c_p))*t_soln.sym[0] # FIXME: term not in the Davies formulation
# put to the left hand side of the advection diffusion equation
#adv_diff.f = term1 - term2 #- term3 

adv_diff.theta = 0.5

# Dirichlet boundary conditions for temperature
# note that that Top is now the source of heat - deep in the mantle
# z = 0 is the surface 
adv_diff.add_dirichlet_bc(0.0, "Bottom")
adv_diff.add_dirichlet_bc(1.0, "Top")

adv_diff.petsc_options["pc_gamg_agg_nsmooths"] = 5

adv_diff.adv_diff_slcn_problem_description() # need to run this?

# %%
adv_diff.estimate_dt()
# Out:
#   0 SNES Function norm 0.0445279
#   1 SNES Function norm 5.06683e-07
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# /Users/jcgraciosa/Documents/codes/uw3-dev/underworld3/underworld3/systems/solvers.py:945: RuntimeWarning: divide by zero encountered in scalar divide
#   dt_adv = min_dx / max_magvel_glob
# 0.00011288397954665979

# %% [markdown]
# ### Set initial temperature field
#
# The initial temperature field is set to a sinusoidal perturbation.

# %%
import math, sympy

pertStrength = 0.1

with meshbox.access(t_soln, t_0):
    t_soln.data[:] = 0.
    t_0.data[:] = 0.

# this is the correct one
with meshbox.access(t_soln):
    for index, coord in enumerate(t_soln.coords):
        # print(index, coord)
        pertCoeff = math.cos( math.pi * coord[0]/boxLength ) * math.sin( math.pi * (1 - coord[1])/boxLength )
    
        t_soln.data[index] = tempMin + deltaTemp*(boxHeight - (1- coord[1])) + pertStrength * pertCoeff
        t_soln.data[index] = max(tempMin, min(tempMax, t_soln.data[index]))

with meshbox.access(t_soln, t_0):
    t_0.data[:,0] = t_soln.data[:,0]

# %% [markdown]
# ### Some plotting and analysis tools

# %%
# check the mesh if in a notebook / serial
# allows you to visualise the mesh with initial perturbation

def plotFig(meshbox = meshbox, v_soln = v_soln, t_soln = t_soln, dTdZ = dTdZ, is_grad = False): 
    """
    is_grad - set flag to True if you want to plot the gradient of the temp field along z-direction 
    """
    if uw.mpi.size == 1:

        import numpy as np
        import pyvista as pv
        import vtk

        pv.global_theme.background = "white"
        pv.global_theme.window_size = [750, 250]
        pv.global_theme.antialiasing = True
        pv.global_theme.jupyter_backend = "panel"
        pv.global_theme.smooth_shading = True

        meshbox.vtk("tmp_box_mesh.vtk")
        pvmesh = pv.read("tmp_box_mesh.vtk")

        velocity = np.zeros((meshbox.data.shape[0], 3))
        velocity[:, 0] = uw.function.evaluate(v_soln.sym[0], meshbox.data)
        velocity[:, 1] = uw.function.evaluate(v_soln.sym[1], meshbox.data)

        pvmesh.point_data["V"] = velocity / 10

        points = np.zeros((t_soln.coords.shape[0], 3))
        points[:, 0] = t_soln.coords[:, 0]
        points[:, 1] = t_soln.coords[:, 1]

        point_cloud = pv.PolyData(points)

        with meshbox.access():
            if is_grad:
                point_cloud.point_data["Tp"] = uw.function.evaluate(dTdZ.fn, points[:, 0:2])
            else:
                point_cloud.point_data["Tp"] = uw.function.evaluate(t_soln.fn, points[:, 0:2])


        # point sources at cell centres

        cpoints = np.zeros((meshbox._centroids.shape[0] // 4 + 1, 3))
        cpoints[:, 0] = meshbox._centroids[::4, 0]
        cpoints[:, 1] = meshbox._centroids[::4, 1]

        cpoint_cloud = pv.PolyData(cpoints)

        pvstream = pvmesh.streamlines_from_source(
            cpoint_cloud,
            vectors="V",
            integrator_type=2,
            integration_direction="forward",
            compute_vorticity=False,
            max_steps=1000,
            surface_streamlines=True,
        )
        # with meshbox.access(t_soln):
        #     if is_grad:
        #         pvmesh.point_data["T"] = uw.function.evaluate(dTdZ.fn, points[:, 0:2])
        #     else:
        #         pvmesh.point_data["T"] = uw.function.evaluate(t_soln.fn, points[:, 0:2])

        pl = pv.Plotter()

        # pl.add_mesh(pvmesh,'Gray', 'wireframe')

        # pl.add_mesh(
        #     pvmesh, cmap="coolwarm", edge_color="Black",
        #     show_edges=True, scalars="T", use_transparency=False, opacity=0.5,
        # )

        pl.add_points(point_cloud, cmap="coolwarm", render_points_as_spheres=True, point_size=10, opacity=1)

        # pl.add_mesh(pvstream, opacity=0.5)
        # pl.add_arrows(arrow_loc2, arrow_length2, mag=1.0e-1)

        # pl.add_points(pdata)

        pl.show(cpos="xy")
        pvmesh.clear_data()
        pvmesh.clear_point_data()
        
plotFig()
# Out:
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2500: PyVistaDeprecationWarning: antialising is deprecated.  Please use `anti_aliasing` instead.
#   warnings.warn(
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2468: PyVistaDeprecationWarning: `anti_aliasing` is now a string or None and must be either "ssaa", "msaa", "fxaa", or None
#   warnings.warn(
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# /var/folders/91/xdyy27357hv1tymzym7xhf5h0000gq/T/ipykernel_24604/788831334.py:17: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.global_theme.jupyter_backend = "panel"
# BokehModel(combine_events=True, render_bundle={'docs_json': {'bff13ea4-5f42-4de2-a5b9-dda9ff1729d8': {'defs': …

# %%
def plot_T_mesh(filename):

    if uw.mpi.size == 1:

        import numpy as np
        import pyvista as pv
        import vtk

        pv.global_theme.background = "white"
        pv.global_theme.window_size = [750, 750]
        pv.global_theme.antialiasing = True
        pv.global_theme.jupyter_backend = "pythreejs"
        pv.global_theme.smooth_shading = True
        pv.global_theme.camera["viewup"] = [0.0, 1.0, 0.0]
        pv.global_theme.camera["position"] = [0.0, 0.0, 5.0]

        meshbox.vtk("tmp_box_mesh.vtk")
        pvmesh = pv.read("tmp_box_mesh.vtk")

        velocity = np.zeros((meshbox.data.shape[0], 3))
        velocity[:, 0] = uw.function.evaluate(v_soln.sym[0], meshbox.data)
        velocity[:, 1] = uw.function.evaluate(v_soln.sym[1], meshbox.data)

        pvmesh.point_data["V"] = velocity / 333
        pvmesh.point_data["T"] = uw.function.evaluate(t_soln.fn, meshbox.data)

        # point sources at cell centres

        cpoints = np.zeros((meshbox._centroids.shape[0] // 4, 3))
        cpoints[:, 0] = meshbox._centroids[::4, 0]
        cpoints[:, 1] = meshbox._centroids[::4, 1]
        cpoint_cloud = pv.PolyData(cpoints)

        pvstream = pvmesh.streamlines_from_source(
            cpoint_cloud,
            vectors="V",
            integrator_type=45,
            integration_direction="forward",
            compute_vorticity=False,
            max_steps=25,
            surface_streamlines=True,
        )

        points = np.zeros((t_soln.coords.shape[0], 3))
        points[:, 0] = t_soln.coords[:, 0]
        points[:, 1] = t_soln.coords[:, 1]

        point_cloud = pv.PolyData(points)

        with meshbox.access():
            point_cloud.point_data["T"] = t_soln.data.copy()

        pl = pv.Plotter()

        pl.add_mesh(
            pvmesh,
            cmap="coolwarm",
            edge_color="Gray",
            show_edges=True,
            scalars="T",
            use_transparency=False,
            opacity=0.5,
        )

        pl.add_points(point_cloud, cmap="coolwarm", render_points_as_spheres=False, point_size=10, opacity=0.5)

        pl.add_mesh(pvstream, opacity=0.4)

        pl.remove_scalar_bar("T")
        pl.remove_scalar_bar("V")

        pl.screenshot(filename="{}.png".format(filename), window_size=(1280, 1280), return_img=False)
        # pl.show()
        pl.close()

        pvmesh.clear_data()
        pvmesh.clear_point_data()

        pv.close_all()

# %% [markdown]
# #### RMS velocity
# The root mean squared velocity, $v_{rms}$, is defined as:
#
#
# \begin{aligned}
# v_{rms}  =  \sqrt{ \frac{ \int_V (\mathbf{v}.\mathbf{v}) dV } {\int_V dV} }
# \end{aligned}
#
# where $\bf{v}$ denotes the velocity field and $V$ is the volume of the box.

# %%
# underworld3 function for calculating the rms velocity 

def v_rms(mesh = meshbox, v_solution = v_soln): 
    # v_soln must be a variable of mesh
    v_rms = math.sqrt(uw.maths.Integral(mesh, v_solution.fn.dot(v_solution.fn)).evaluate())
    return v_rms

#print(f'initial v_rms = {v_rms()}')

# %% [markdown]
# ### Main simulation loop

# %%
t_step = 0
time = 0.

timeVal =  np.zeros(nsteps)*np.nan
vrmsVal =  np.zeros(nsteps)*np.nan

# %%
#### Convection model / update in time


# NOTE: There is a strange interaction here between the solvers if the zero_guess is set to False


while t_step < nsteps:
    vrmsVal[t_step] = v_rms()
    timeVal[t_step] = time

    stokes.solve(zero_init_guess=True) # originally True
    delta_t = 0.5 * stokes.estimate_dt()
    adv_diff.solve(timestep=delta_t, zero_init_guess=False) # originally False

    # stats then loop
    tstats = t_soln.stats()

    if uw.mpi.rank == 0:
        print("Timestep {}, dt {}".format(t_step, delta_t))
        
        print(f't_rms = {t_soln.stats()[6]}, v_rms = {v_rms()}')

    if t_step > 1 and abs((vrmsVal[t_step] - vrmsVal[t_step - 1])/vrmsVal[t_step]) < epsilon_lr:
        break

    t_step += 1
    time   += delta_t


# save final mesh variables in the run 
# os.makedirs("../meshes", exist_ok = True)

# expt_name = "Ra1e4_res" + str(res)
# savefile = "{}_ts{}.h5".format(expt_name,t_step)
# meshbox.save(savefile)
# v_soln.save(savefile)
# t_soln.save(savefile)
# meshbox.generate_xdmf(savefile)
# Out:
#   0 SNES Function norm 261.125
#   1 SNES Function norm 0.000190816
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.417901
#   1 SNES Function norm 1.11681e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 0, dt 0.00015361076396409634
# t_rms = 0.579484905552599, v_rms = 23.221761829165903
#   0 SNES Function norm 261.16
#   1 SNES Function norm 0.00024485
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.439057
#   1 SNES Function norm 9.60821e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 1, dt 0.0001454003011339462
# t_rms = 0.5796087204977513, v_rms = 24.56239379056287
#   0 SNES Function norm 261.199
#   1 SNES Function norm 0.00221731
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.461852
#   1 SNES Function norm 9.9855e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 2, dt 0.0001380475491606681
# t_rms = 0.5797472899194009, v_rms = 25.898506178332575
#   0 SNES Function norm 261.243
#   1 SNES Function norm 0.00121884
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.484548
#   1 SNES Function norm 1.05547e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 3, dt 0.00013142857979705336
# t_rms = 0.5799005456298928, v_rms = 27.230034736439393
#   0 SNES Function norm 261.291
#   1 SNES Function norm 0.000320737
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.507046
#   1 SNES Function norm 1.17364e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 4, dt 0.0001254245863263183
# t_rms = 0.5800680415318131, v_rms = 28.556839465929382
#   0 SNES Function norm 261.343
#   1 SNES Function norm 0.000184541
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.529412
#   1 SNES Function norm 7.38843e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 5, dt 0.0001199652033244675
# t_rms = 0.5802494990828301, v_rms = 29.87861350291101
#   0 SNES Function norm 261.399
#   1 SNES Function norm 0.000383809
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.551623
#   1 SNES Function norm 1.19199e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 6, dt 0.00011497672594101735
# t_rms = 0.580444685394086, v_rms = 31.195234876983868
#   0 SNES Function norm 261.459
#   1 SNES Function norm 0.000148701
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.573697
#   1 SNES Function norm 1.52874e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 7, dt 0.00011040275451219605
# t_rms = 0.5806533503169857, v_rms = 32.50653931826294
#   0 SNES Function norm 261.522
#   1 SNES Function norm 0.00128872
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.59564
#   1 SNES Function norm 1.62087e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 8, dt 0.00010618977473643696
# t_rms = 0.580875325769116, v_rms = 33.81242242398243
#   0 SNES Function norm 261.588
#   1 SNES Function norm 0.00167916
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.617398
#   1 SNES Function norm 1.45797e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 9, dt 0.00010231102764993478
# t_rms = 0.5811103241931118, v_rms = 35.1126915064123
#   0 SNES Function norm 261.659
#   1 SNES Function norm 0.000423353
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.639032
#   1 SNES Function norm 1.87814e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 10, dt 9.870606546826564e-05
# t_rms = 0.5813582450020545, v_rms = 36.40731973623207
#   0 SNES Function norm 261.732
#   1 SNES Function norm 0.000186109
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.660523
#   1 SNES Function norm 2.13776e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 11, dt 9.536379488656361e-05
# t_rms = 0.5816188716367351, v_rms = 37.696052908469774
#   0 SNES Function norm 261.809
#   1 SNES Function norm 0.00132189
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.68185
#   1 SNES Function norm 2.02456e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 12, dt 9.225537874178701e-05
# t_rms = 0.5818920135191361, v_rms = 38.97883715619782
#   0 SNES Function norm 261.889
#   1 SNES Function norm 0.00136659
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.703089
#   1 SNES Function norm 2.06287e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 13, dt 8.934750775491648e-05
# t_rms = 0.5821775842913588, v_rms = 40.2555993923455
#   0 SNES Function norm 261.972
#   1 SNES Function norm 0.00176857
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.724088
#   1 SNES Function norm 8.42668e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 14, dt 8.663491771153724e-05
# t_rms = 0.5824753327753867, v_rms = 41.52616662944005
#   0 SNES Function norm 262.058
#   1 SNES Function norm 0.00134931
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.745043
#   1 SNES Function norm 8.59646e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 15, dt 8.408740209671145e-05
# t_rms = 0.582785228646888, v_rms = 42.79047599109247
#   0 SNES Function norm 262.147
#   1 SNES Function norm 0.00133617
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.765766
#   1 SNES Function norm 8.63539e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 16, dt 8.17020235253875e-05
# t_rms = 0.5831070256269154, v_rms = 44.048444655163024
#   0 SNES Function norm 262.24
#   1 SNES Function norm 0.000378907
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.7864
#   1 SNES Function norm 9.39813e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 17, dt 7.945247574213689e-05
# t_rms = 0.583440629021782, v_rms = 45.29996497846984
#   0 SNES Function norm 262.335
#   1 SNES Function norm 0.00117015
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.806856
#   1 SNES Function norm 1.73729e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 18, dt 7.733313507948796e-05
# t_rms = 0.5837858807925451, v_rms = 46.54492021356049
#   0 SNES Function norm 262.433
#   1 SNES Function norm 0.00024884
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.827187
#   1 SNES Function norm 9.23348e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 19, dt 7.533464342232647e-05
# t_rms = 0.5841426866855236, v_rms = 47.78325281312445
#   0 SNES Function norm 262.534
#   1 SNES Function norm 0.00117715
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.847335
#   1 SNES Function norm 2.30617e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 20, dt 7.344338447394133e-05
# t_rms = 0.5845108925857916, v_rms = 49.014851459348016
#   0 SNES Function norm 262.638
#   1 SNES Function norm 0.00135227
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.867356
#   1 SNES Function norm 9.53958e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 21, dt 7.165667697312715e-05
# t_rms = 0.5848903582477365, v_rms = 50.23963135761868
#   0 SNES Function norm 262.745
#   1 SNES Function norm 0.00022819
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.887238
#   1 SNES Function norm 9.6101e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 22, dt 6.995929434426566e-05
# t_rms = 0.5852809872457424, v_rms = 51.45752964204339
#   0 SNES Function norm 262.854
#   1 SNES Function norm 0.000436256
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.906953
#   1 SNES Function norm 9.4224e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 23, dt 6.834900703946009e-05
# t_rms = 0.5856826485825315, v_rms = 52.66846326790032
#   0 SNES Function norm 262.967
#   1 SNES Function norm 0.00136306
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.926493
#   1 SNES Function norm 9.4788e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 24, dt 6.681985113912909e-05
# t_rms = 0.5860952077364371, v_rms = 53.87233459719623
#   0 SNES Function norm 263.081
#   1 SNES Function norm 0.00046468
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.94592
#   1 SNES Function norm 9.5084e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 25, dt 6.536268567957352e-05
# t_rms = 0.5865185583758366, v_rms = 55.069052379480645
#   0 SNES Function norm 263.199
#   1 SNES Function norm 0.000434013
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.965165
#   1 SNES Function norm 9.45469e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 26, dt 6.397574202029754e-05
# t_rms = 0.5869525857538996, v_rms = 56.258564680265145
#   0 SNES Function norm 263.319
#   1 SNES Function norm 0.000343599
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.984267
#   1 SNES Function norm 9.4154e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 27, dt 6.265304426641894e-05
# t_rms = 0.5873971503754853, v_rms = 57.44077440708146
#   0 SNES Function norm 263.442
#   1 SNES Function norm 0.00145908
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.00317
#   1 SNES Function norm 9.34813e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 28, dt 6.13915145581294e-05
# t_rms = 0.5878521508237797, v_rms = 58.61563189820605
#   0 SNES Function norm 263.567
#   1 SNES Function norm 0.00138777
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.02201
#   1 SNES Function norm 9.25031e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 29, dt 6.018345397374177e-05
# t_rms = 0.5883174549419318, v_rms = 59.78301294054465
#   0 SNES Function norm 263.695
#   1 SNES Function norm 0.000446184
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.04059
#   1 SNES Function norm 9.11767e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 30, dt 5.9030920072006636e-05
# t_rms = 0.5887929610762525, v_rms = 60.94292532006969
#   0 SNES Function norm 263.825
#   1 SNES Function norm 0.00270253
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.059
#   1 SNES Function norm 8.95812e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 31, dt 5.792865176382692e-05
# t_rms = 0.5892785440515674, v_rms = 62.09526373248654
#   0 SNES Function norm 263.957
#   1 SNES Function norm 0.00144126
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.0773
#   1 SNES Function norm 8.8797e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 32, dt 5.68699776223809e-05
# t_rms = 0.589774094964402, v_rms = 63.23991368179499
#   0 SNES Function norm 264.092
#   1 SNES Function norm 0.00165852
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.09544
#   1 SNES Function norm 8.88205e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 33, dt 5.5856048597634524e-05
# t_rms = 0.590279489395865, v_rms = 64.37686509288152
#   0 SNES Function norm 264.23
#   1 SNES Function norm 0.00140001
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.11339
#   1 SNES Function norm 8.85919e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 34, dt 5.4883068844369275e-05
# t_rms = 0.5907946170580743, v_rms = 65.50604506548108
#   0 SNES Function norm 264.37
#   1 SNES Function norm 0.000559065
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.1312
#   1 SNES Function norm 8.79698e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 35, dt 5.394793409078381e-05
# t_rms = 0.5913193718244978, v_rms = 66.62737764037345
#   0 SNES Function norm 264.512
#   1 SNES Function norm 0.0015551
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.14885
#   1 SNES Function norm 8.72902e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 36, dt 5.3049628374064404e-05
# t_rms = 0.5918536288906845, v_rms = 67.74081648972556
#   0 SNES Function norm 264.656
#   1 SNES Function norm 0.000509159
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.16627
#   1 SNES Function norm 8.67377e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 37, dt 5.218721383808264e-05
# t_rms = 0.5923972763332892, v_rms = 68.84631009900836
#   0 SNES Function norm 264.802
#   1 SNES Function norm 0.000550916
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.18354
#   1 SNES Function norm 8.63573e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 38, dt 5.135678417255044e-05
# t_rms = 0.592950199883777, v_rms = 69.94377821089878
#   0 SNES Function norm 264.951
#   1 SNES Function norm 0.000293347
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.20064
#   1 SNES Function norm 8.61526e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 39, dt 5.055737434798396e-05
# t_rms = 0.5935122838937212, v_rms = 71.03316240665977
#   0 SNES Function norm 265.102
#   1 SNES Function norm 0.00142823
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.21759
#   1 SNES Function norm 8.60979e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 40, dt 4.978670840561372e-05
# t_rms = 0.5940834083283234, v_rms = 72.11441197043555
#   0 SNES Function norm 265.255
#   1 SNES Function norm 0.000197943
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.23431
#   1 SNES Function norm 8.61591e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 41, dt 4.9045079236570154e-05
# t_rms = 0.5946634611260277, v_rms = 73.1875028293186
#   0 SNES Function norm 265.41
#   1 SNES Function norm 0.000213942
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.25087
#   1 SNES Function norm 8.63084e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 42, dt 4.832918095175119e-05
# t_rms = 0.5952523289672564, v_rms = 74.25234322277508
#   0 SNES Function norm 265.567
#   1 SNES Function norm 0.0013551
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.26723
#   1 SNES Function norm 8.65469e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 43, dt 4.763908884140444e-05
# t_rms = 0.5958498901592418, v_rms = 75.30890436104927
#   0 SNES Function norm 265.727
#   1 SNES Function norm 0.000561944
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.28345
#   1 SNES Function norm 8.68738e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 44, dt 4.6971686853407925e-05
# t_rms = 0.5964560346257352, v_rms = 76.35710947977005
#   0 SNES Function norm 265.888
#   1 SNES Function norm 0.00134273
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.29948
#   1 SNES Function norm 8.72964e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 45, dt 4.632711200804969e-05
# t_rms = 0.5970706485756666, v_rms = 77.39694131561367
#   0 SNES Function norm 266.051
#   1 SNES Function norm 0.000369417
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.3153
#   1 SNES Function norm 8.78137e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 46, dt 4.570539042834034e-05
# t_rms = 0.5976936109943207, v_rms = 78.42836879530704
#   0 SNES Function norm 266.217
#   1 SNES Function norm 0.000461187
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.33094
#   1 SNES Function norm 8.84136e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 47, dt 4.510363552138267e-05
# t_rms = 0.5983248070093649, v_rms = 79.45132010815318
#   0 SNES Function norm 266.384
#   1 SNES Function norm 0.000204707
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.34639
#   1 SNES Function norm 8.90915e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 48, dt 4.4521644855998694e-05
# t_rms = 0.598964117171962, v_rms = 80.46575247395845
#   0 SNES Function norm 266.553
#   1 SNES Function norm 0.000575653
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.36165
#   1 SNES Function norm 8.98394e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 49, dt 4.3958685574808995e-05
# t_rms = 0.5996114270918005, v_rms = 81.47162314867364
#   0 SNES Function norm 266.724
#   1 SNES Function norm 0.00020084
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.37672
#   1 SNES Function norm 9.06479e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 50, dt 4.341355369353967e-05
# t_rms = 0.6002666173012134, v_rms = 82.46891945438534
#   0 SNES Function norm 266.897
#   1 SNES Function norm 0.00139665
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.39156
#   1 SNES Function norm 9.15076e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 51, dt 4.2886068703817005e-05
# t_rms = 0.6009295731125373, v_rms = 83.45758044232204
#   0 SNES Function norm 267.071
#   1 SNES Function norm 0.000655334
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.40627
#   1 SNES Function norm 9.2408e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 52, dt 4.237432018403736e-05
# t_rms = 0.6016001722957021, v_rms = 84.43755703461149
#   0 SNES Function norm 267.247
#   1 SNES Function norm 0.000817187
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.42075
#   1 SNES Function norm 9.33369e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 53, dt 4.187884091399116e-05
# t_rms = 0.6022782997141661, v_rms = 85.4088523145957
#   0 SNES Function norm 267.426
#   1 SNES Function norm 0.000669848
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.43503
#   1 SNES Function norm 9.42809e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 54, dt 4.139832611918377e-05
# t_rms = 0.6029638345285352, v_rms = 86.37140694904613
#   0 SNES Function norm 267.605
#   1 SNES Function norm 0.0104941
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.44912
#   1 SNES Function norm 9.52283e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 55, dt 4.093266314320056e-05
# t_rms = 0.603656674885302, v_rms = 87.3251942937233
#   0 SNES Function norm 267.787
#   1 SNES Function norm 0.000124328
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.46299
#   1 SNES Function norm 9.61681e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 56, dt 4.048054180921434e-05
# t_rms = 0.6043566742126038, v_rms = 88.27020091544057
#   0 SNES Function norm 267.97
#   1 SNES Function norm 0.0107576
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.47666
#   1 SNES Function norm 9.7094e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 57, dt 4.004183331135498e-05
# t_rms = 0.6050637151778749, v_rms = 89.20637471014447
#   0 SNES Function norm 268.155
#   1 SNES Function norm 0.00221346
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.4901
#   1 SNES Function norm 9.79998e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 58, dt 3.9616327641087656e-05
# t_rms = 0.6057776929174283, v_rms = 90.13367263714183
#   0 SNES Function norm 268.341
#   1 SNES Function norm 0.000557653
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.5034
#   1 SNES Function norm 9.88857e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 59, dt 3.920283784745739e-05
# t_rms = 0.6064984924349172, v_rms = 91.05210200877691
#   0 SNES Function norm 268.529
#   1 SNES Function norm 0.0136302
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.51646
#   1 SNES Function norm 9.97471e-06
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 60, dt 3.880138559827699e-05
# t_rms = 0.6072259912058958, v_rms = 91.96163269663948
#   0 SNES Function norm 268.718
#   1 SNES Function norm 0.011206
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.5293
#   1 SNES Function norm 1.00583e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 61, dt 3.841148186085969e-05
# t_rms = 0.6079600721141959, v_rms = 92.86225117523334
#   0 SNES Function norm 268.909
#   1 SNES Function norm 0.000990795
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.54193
#   1 SNES Function norm 1.01388e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 62, dt 3.803222760475059e-05
# t_rms = 0.6087005930421739, v_rms = 93.75393254664414
#   0 SNES Function norm 269.102
#   1 SNES Function norm 0.0140466
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.55436
#   1 SNES Function norm 1.02161e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 63, dt 3.766379859780657e-05
# t_rms = 0.6094474558760632, v_rms = 94.63662982451973
#   0 SNES Function norm 269.296
#   1 SNES Function norm 0.00087418
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.56656
#   1 SNES Function norm 1.02892e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 64, dt 3.73055066182437e-05
# t_rms = 0.6102005259878422, v_rms = 95.5103590467252
#   0 SNES Function norm 269.491
#   1 SNES Function norm 0.000641176
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.57856
#   1 SNES Function norm 1.03567e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 65, dt 3.695711706241105e-05
# t_rms = 0.6109596896089794, v_rms = 96.37505838961987
#   0 SNES Function norm 269.688
#   1 SNES Function norm 0.014397
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.59033
#   1 SNES Function norm 1.04159e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 66, dt 3.661802226023374e-05
# t_rms = 0.6117248107740971, v_rms = 97.23076697166776
#   0 SNES Function norm 269.885
#   1 SNES Function norm 0.00154782
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.60189
#   1 SNES Function norm 1.0463e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 67, dt 3.628877056017042e-05
# t_rms = 0.6124957883488141, v_rms = 98.07741039880202
#   0 SNES Function norm 270.085
#   1 SNES Function norm 0.000308592
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.61324
#   1 SNES Function norm 1.04934e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 68, dt 3.5967530158183775e-05
# t_rms = 0.6132724953930602, v_rms = 98.91500121551753
#   0 SNES Function norm 270.285
#   1 SNES Function norm 0.000928717
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.62436
#   1 SNES Function norm 1.05092e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 69, dt 3.565523615707829e-05
# t_rms = 0.6140548134541084, v_rms = 99.74354423551824
#   0 SNES Function norm 270.487
#   1 SNES Function norm 0.000694561
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.63527
#   1 SNES Function norm 1.05275e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 70, dt 3.535119990204881e-05
# t_rms = 0.6148426176602492, v_rms = 100.56301331445894
#   0 SNES Function norm 270.69
#   1 SNES Function norm 0.000436106
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.64595
#   1 SNES Function norm 1.05735e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 71, dt 3.505517191699524e-05
# t_rms = 0.6156357854883024, v_rms = 101.3734065846789
#   0 SNES Function norm 270.894
#   1 SNES Function norm 0.00107166
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.6564
#   1 SNES Function norm 1.0651e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 72, dt 3.476677640009419e-05
# t_rms = 0.6164341943564383, v_rms = 102.1747170355872
#   0 SNES Function norm 271.1
#   1 SNES Function norm 0.000854844
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.66664
#   1 SNES Function norm 1.07435e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 73, dt 3.44859845073686e-05
# t_rms = 0.6172377289490077, v_rms = 102.96691725450398
#   0 SNES Function norm 271.306
#   1 SNES Function norm 0.0154651
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.67665
#   1 SNES Function norm 1.08373e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 74, dt 3.421245499786463e-05
# t_rms = 0.6180462728727845, v_rms = 103.75001035823858
#   0 SNES Function norm 271.514
#   1 SNES Function norm 0.00339548
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.68643
#   1 SNES Function norm 1.09268e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 75, dt 3.3946083164277504e-05
# t_rms = 0.6188596881737682, v_rms = 104.52402754451127
#   0 SNES Function norm 271.723
#   1 SNES Function norm 0.000989621
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.69599
#   1 SNES Function norm 1.1011e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 76, dt 3.3685931136803126e-05
# t_rms = 0.6196778533899783, v_rms = 105.28891534341426
#   0 SNES Function norm 271.933
#   1 SNES Function norm 0.00167156
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.70532
#   1 SNES Function norm 1.10911e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 77, dt 3.343282027431741e-05
# t_rms = 0.6205006582840903, v_rms = 106.04467153254596
#   0 SNES Function norm 272.143
#   1 SNES Function norm 0.00141544
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.71443
#   1 SNES Function norm 1.11677e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 78, dt 3.318605404493781e-05
# t_rms = 0.6213279778929706, v_rms = 106.79132676579742
#   0 SNES Function norm 272.355
#   1 SNES Function norm 0.00179638
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.7233
#   1 SNES Function norm 1.12414e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 79, dt 3.29453494172806e-05
# t_rms = 0.6221596879106642, v_rms = 107.52887937062037
#   0 SNES Function norm 272.568
#   1 SNES Function norm 0.0130909
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.73195
#   1 SNES Function norm 1.13129e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 80, dt 3.27105692201624e-05
# t_rms = 0.6229956548984605, v_rms = 108.25732596993974
#   0 SNES Function norm 272.781
#   1 SNES Function norm 0.000966283
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.74037
#   1 SNES Function norm 1.13826e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 81, dt 3.248194469814809e-05
# t_rms = 0.6238357836200771, v_rms = 108.9766306203157
#   0 SNES Function norm 272.996
#   1 SNES Function norm 0.000181015
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.74855
#   1 SNES Function norm 1.14506e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 82, dt 3.225882351805424e-05
# t_rms = 0.6246799376666069, v_rms = 109.68685110213976
#   0 SNES Function norm 273.211
#   1 SNES Function norm 0.0162812
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.75651
#   1 SNES Function norm 1.15171e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 83, dt 3.204128228681723e-05
# t_rms = 0.6255280078640701, v_rms = 110.38796087876406
#   0 SNES Function norm 273.427
#   1 SNES Function norm 0.0160063
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.76423
#   1 SNES Function norm 1.15823e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 84, dt 3.182917397491275e-05
# t_rms = 0.6263798780984153, v_rms = 111.0799815620742
#   0 SNES Function norm 273.644
#   1 SNES Function norm 0.0165315
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.77172
#   1 SNES Function norm 1.16458e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 85, dt 3.162167989919289e-05
# t_rms = 0.6272353722513032, v_rms = 111.76296348730143
#   0 SNES Function norm 273.862
#   1 SNES Function norm 0.00115122
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.77898
#   1 SNES Function norm 1.17083e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 86, dt 3.141970017469638e-05
# t_rms = 0.6280944199295788, v_rms = 112.43680176937396
#   0 SNES Function norm 274.081
#   1 SNES Function norm 0.00112672
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.78601
#   1 SNES Function norm 1.17693e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 87, dt 3.122259117860577e-05
# t_rms = 0.6289568879157245, v_rms = 113.10156745224855
#   0 SNES Function norm 274.3
#   1 SNES Function norm 0.000846542
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.79281
#   1 SNES Function norm 1.1829e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 88, dt 3.103030580879364e-05
# t_rms = 0.6298226600727879, v_rms = 113.75727714109442
#   0 SNES Function norm 274.52
#   1 SNES Function norm 0.0169245
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.79937
#   1 SNES Function norm 1.18872e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 89, dt 3.084258335921867e-05
# t_rms = 0.6306916048786083, v_rms = 114.40394267388386
#   0 SNES Function norm 274.74
#   1 SNES Function norm 0.000420013
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.8057
#   1 SNES Function norm 1.1944e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 90, dt 3.0659504378185226e-05
# t_rms = 0.6315636188630089, v_rms = 115.04154856588761
#   0 SNES Function norm 274.962
#   1 SNES Function norm 0.0170704
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.81179
#   1 SNES Function norm 1.19991e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 91, dt 3.0480518007000304e-05
# t_rms = 0.6324385549371533, v_rms = 115.67017071864223
#   0 SNES Function norm 275.183
#   1 SNES Function norm 0.0171925
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.81766
#   1 SNES Function norm 1.20528e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 92, dt 3.0306354425091815e-05
# t_rms = 0.6333163365373455, v_rms = 116.28971728175028
#   0 SNES Function norm 275.406
#   1 SNES Function norm 0.0172934
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.82329
#   1 SNES Function norm 1.21045e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 93, dt 3.013575875872125e-05
# t_rms = 0.6341968139270078, v_rms = 116.9003168977335
#   0 SNES Function norm 275.629
#   1 SNES Function norm 0.00065439
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.82869
#   1 SNES Function norm 1.21548e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 94, dt 2.9969707823993297e-05
# t_rms = 0.6350798608285085, v_rms = 117.50194530159573
#   0 SNES Function norm 275.852
#   1 SNES Function norm 0.000752776
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.83385
#   1 SNES Function norm 1.22029e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 95, dt 2.9807471367854564e-05
# t_rms = 0.6359653702165201, v_rms = 118.09458730651025
#   0 SNES Function norm 276.076
#   1 SNES Function norm 0.000695291
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.83879
#   1 SNES Function norm 1.22493e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 96, dt 2.964917517538618e-05
# t_rms = 0.6368532282321266, v_rms = 118.67827225537727
#   0 SNES Function norm 276.3
#   1 SNES Function norm 0.00100166
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.84349
#   1 SNES Function norm 1.22934e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 97, dt 2.9494526472378397e-05
# t_rms = 0.6377433056703403, v_rms = 119.25304636128782
#   0 SNES Function norm 276.525
#   1 SNES Function norm 0.0176886
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.84796
#   1 SNES Function norm 1.23355e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 98, dt 2.934353322523354e-05
# t_rms = 0.6386354805887544, v_rms = 119.81891063039527
#   0 SNES Function norm 276.75
#   1 SNES Function norm 0.000514186
# Nonlinear stokes_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 1.85219
#   1 SNES Function norm 1.23754e-05
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 99, dt 2.9196344091641224e-05
# t_rms = 0.6395296533950389, v_rms = 120.37585731825196

# %% [markdown]
# ### Post-run analysis
#
# **Benchmark values**
# The loop above outputs $v_{rms}$ as a general statistic for the system. For further comparison, the benchmark values for the RMS velocity, $v_{rms}$, Nusselt number, $Nu$, and non-dimensional gradients at the cell corners, $q_1$ and $q_2$, are shown below for different Rayleigh numbers. All benchmark values shown below were determined in Blankenbach *et al.* 1989 by extroplation of numerical results.
#
# | $Ra$ | $v_{rms}$ | $Nu$ | $q_1$ | $q_2$ |
# | ------------- |:-------------:|:-----:|:-----:|:-----:|
# | 10$^4$ | 42.865 | 4.884 | 8.059 | 0.589 |
# | 10$^5$ | 193.215 | 10.535 | 19.079 | 0.723 |
# | 10$^6$ | 833.990 | 21.972 | 45.964 | 0.877 |

# %%
# set-up variables to use in calculating the benchmark values 

if do_rerun: # re-run with higher resolution mesh
    meshbox_use = meshbox_hr
    dTdZ_use = dTdZ_hr 
    t_soln_use = t_soln_hr
    sigma_zz_use = sigma_zz_hr
    sigma_zz_fn = stokes_hr.stress[1, 1]
else: # 
    meshbox_use = meshbox 
    dTdZ_use = dTdZ 
    t_soln_use = t_soln
    sigma_zz_use = sigma_zz

    sigma_zz_fn = stokes.stress[1, 1]

### define the Projection object for calculating the temperature gradient
# define upper and lower surface functions
x, z = meshbox_use.X

# gradient of temp field 
t_soln_grad = uw.systems.Projection(meshbox_use, dTdZ_use)
delT = t_soln_use.sym.diff(z)[0]
t_soln_grad.uw_function = delT
t_soln_grad.smoothing = 1.0e-3
t_soln_grad.petsc_options.delValue("ksp_monitor")

t_soln_grad.solve()
# Out:
#   0 SNES Function norm 0.109011
#   1 SNES Function norm 1.3591e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1

# %% [markdown]
# ### Calculate the $Nu$ value
# The Nusselt number is defined as:
#
# \begin{aligned}
# Nu  =   -h\frac{ \int_{0}^{l} \partial_{z}T(x, z = h) dx} {\int_{0}^{l} T(x, z = 0) dx}
# \end{aligned}

# %%
# function for calculating the surface integral 
# from Ex_Shear_Band_Notch_Benchmark
 
def surface_integral(mesh, uw_function, mask_fn):

    calculator = uw.maths.Integral(mesh, uw_function * mask_fn)
    value = calculator.evaluate()

    calculator.fn = mask_fn
    norm = calculator.evaluate()

    integral = value / norm

    return integral

# %%
up_surface_defn_fn = sympy.exp(-1e6*((z - 1)**2)) # at z = 1
lw_surface_defn_fn = sympy.exp(-1e6*((z)**2)) # at z = 0

# display(up_surface_defn_fn)
# display(lw_surface_defn_fn)

up_int = surface_integral(meshbox_use, dTdZ_use.sym[0], up_surface_defn_fn)
lw_int = surface_integral(meshbox_use, t_soln_use.sym[0], lw_surface_defn_fn)

Nu = -up_int/lw_int

if uw.mpi.rank == 0:
    print("Calculated value of Nu: {}".format(Nu))
# Out:
# Calculated value of Nu: 4.084491366061627

# %% [markdown]
# ### Calculate the non-dimensional gradients at the cell corners, $q_i$
# The non-dimensional temperature gradient at the cell corner, $q_i$, is defined as:
# \begin{aligned}
# q  =  \frac{-h}{\Delta T} \left( \frac{\partial T}{\partial z} \right)
# \end{aligned}
#
# Note that these values depend on the non-dimensional temperature gradient in the vertical direction, $\frac{\partial T}{\partial z}$.
# These gradients are evaluated at the following points:
#
# $q_1$ at $x=0$, $z=h$; $q_2$ at $x=l$, $z=h$;
#
# $q_3$ at $x=l$, $z=0$; $q_4$ at $x=0$, $z=0$.

# %%
# calculate q values which depend on the temperature gradient fields

q1 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ_use.sym[0], np.array([[0., 0.999999*boxHeight]]))[0]
q2 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ_use.sym[0], np.array([[0.999999*boxLength, 0.999999*boxHeight]]))[0]
q3 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ_use.sym[0], np.array([[0.999999*boxLength, 0.]]))[0]
q4 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ_use.sym[0], np.array([[0., 0.]]))[0]

if uw.mpi.rank == 0:
    print('Rayleigh number = {0:.1e}'.format(Ra))
    print('q1 = {0:.3f}; q2 = {1:.3f}'.format(q1, q2))
    print('q3 = {0:.3f}; q4 = {1:.3f}'.format(q3, q4))
# Out:
# Rayleigh number = 1.0e+04
# q1 = 6.206; q2 = 0.647
# q3 = 6.206; q4 = 0.647

# %% [markdown]
# ### Calculate the stress for comparison with benchmark value
#
# The stress field for whole box in dimensionless units (King 2009) is:
# \begin{equation}
# \tau_{ij} = \eta \frac{1}{2} \left[ \frac{\partial v_j}{\partial x_i} + \frac{\partial v_i}{\partial x_j}\right].
# \end{equation}
# For vertical normal stress it becomes:
# \begin{equation}
# \tau_{zz} = \eta \frac{1}{2} \left[ \frac{\partial v_z}{\partial z} + \frac{\partial v_z}{\partial z}\right] = \eta \frac{\partial v_z}{\partial z}.
# \end{equation}
# This is calculated below.

# %%
# projection for the stress in the zz direction
x, y = meshbox_use.X

stress_calc = uw.systems.Projection(meshbox_use, sigma_zz_use)
stress_calc.uw_function = sigma_zz_fn
stress_calc.smoothing = 1.0e-3
stress_calc.petsc_options.delValue("ksp_monitor")
stress_calc.solve()
# Out:
#   0 SNES Function norm 88.3953
#   1 SNES Function norm 0.000800098
# Nonlinear SProj_2_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1

# %% [markdown]
# The vertical normal stress is dimensionalised as:
#
# $$
#     \sigma_{t} = \frac{\eta_0 \kappa}{\rho g h^2}\tau _{zz} \left( x, z=h\right)
# $$
#
# where all constants are defined below.
#
# Finally, we calculate the topography defined using $h = \sigma_{top} / (\rho g)$. The topography of the top boundary calculated in the left and right corners as given in Table 9 of Blankenbach et al 1989 are:
#
# | $Ra$          |    $\xi_1$  | $\xi_2$  |  $x$ ($\xi = 0$) |
# | ------------- |:-----------:|:--------:|:--------------:|
# | 10$^4$  | 2254.02   | -2903.23  | 0.539372          |
# | 10$^5$  | 1460.99   | -2004.20  | 0.529330          |
# | 10$^6$  | 931.96   | -1283.80  | 0.506490          |

# %%
# subtract the average value for the benchmark since the mean is set to zero 

mean_sigma_zz_top = -surface_integral(meshbox_use, 
                                     sigma_zz_use.sym[0], 
                                     up_surface_defn_fn)/boxLength

# %%
# Set parameters in SI units

grav = 10        # m.s^-2
height = 1.e6    # m 
rho  = 4.0e3     # g.m^-3
kappa  = 1.0e-6  # m^2.s^-1

eta0=1.e23

def calculate_topography(coord): # only coord has local scope

    sigma_zz_top = -uw.function.evaluate(sigma_zz_use.sym[0], coord) - mean_sigma_zz_top
    
    # dimensionalise 
    dim_sigma_zz_top  = ((eta0 * kappa) / (height**2)) * sigma_zz_top
    topography = dim_sigma_zz_top / (rho * grav)
    
    return topography

# %%
# topography at the top corners 
e1 = calculate_topography(np.array([[0, 0.999999*boxHeight]]))
e2 = calculate_topography(np.array([[0.999999*boxLength, 0.999999*boxHeight]]))

# calculate the x-coordinate with zero stress
with meshbox_use.access():
    cond = meshbox_use.data[:, 1] == meshbox_use.data[:, 1].max()
    up_surface_coords = meshbox_use.data[cond]
    up_surface_coords[:, 1] = 0.999999*up_surface_coords[:, 1]

abs_topo = abs(calculate_topography(up_surface_coords))

min_abs_topo_coord = up_surface_coords[np.where(abs_topo == abs_topo.min())[0]].flatten()

if uw.mpi.rank == 0:
    print("Topography [x=0], [x=max] = {0:.2f}, {1:.2f}".format(e1[0], e2[0]))
    print("x where topo = 0 is at {0:.6f}".format(min_abs_topo_coord[0]))
# Out:
# Topography [x=0], [x=max] = 2423.66, -3013.92
# x where topo = 0 is at 0.562500
