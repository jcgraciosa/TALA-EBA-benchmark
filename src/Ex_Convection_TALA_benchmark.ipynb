# %% [markdown]
# # King / Blankenbach Benchmark Case 1
#
# ## Isoviscous thermal convection with TALA formulation.
#
# Two-dimensional, compressible, bottom heated, steady isoviscous thermal convection in a 1 x 1 box, see case 1 of [King et al. (2009)](https://doi.org/10.1111/j.1365-246X.2009.04413.x) / [Blankenbach et al. (1989) benchmark](https://academic.oup.com/gji/article/98/1/23/622167).
#
# Keywords: Truncated Anelastic Liquid Approximation, TALA, Convection

# %%
import petsc4py
from petsc4py import PETSc

import underworld3 as uw
from underworld3.systems import Stokes
from underworld3 import function

import os 
import numpy as np
import sympy
from sympy.vector import gradient, divergence, dot
from copy import deepcopy

# %% [markdown]
# ### Set parameters to use

# %%
Di = 0.5 # dissipation factor 
Ra = 1e4 #### Rayleigh number

# other non-dimensional parameters
alphaBar = 1.      # this is set to 1 in King et al. 
gammaR = 1.        # Gruneisen parameter
cp = 1             # set to 1 for now
Ts = 0.091         # non-dimensionalized surface temp (273 K/3000 K as per Davies et al)
rho0  = 1          # non-dimensionalized surface density 

k = 1.0 #### diffusivity

boxLength = 1.0
boxHeight = 1.0
tempMin   = 0.
tempMax   = 1.
deltaTemp = tempMax - tempMin

viscosity = 1

tol = 1e-4          ### solver tolerance
res= 16             ### x and y res of box
nsteps = 1000        ### maximum number of time steps to run the first model 
epsilon_lr = 1e-8   ### criteria for early stopping; relative change of the Nusselt number in between iterations  

##########
# parameters needed for saving checkpoints
# can set outdir to None if you don't want to save anything
outdir = "/Users/jcgraciosa/Documents/codes/uw3-dev/TALA_test" 
outfile = outdir + "/tala_" + str(res)
save_every = 10
#
prev_res = 16 # if infile is not None, then this should be set to the previous model resolution
infile = outdir + "/tala_" + str(prev_res) # set infile to a value if there's a checkpoint from a previous run that you want to start from
# example infile settings: 
# infile = outfile # will read outfile, but this file will be overwritten at the end of this run 
# infile = outdir + "/convection_16" # file is that of 16 x 16 mesh   

os.makedirs(outdir, exist_ok = True)

# %% [markdown]
# ### Create mesh and variables

# %%
meshbox = uw.meshing.UnstructuredSimplexBox(
                                                minCoords=(0.0, 0.0), 
                                                maxCoords=(boxLength, boxHeight), 
                                                cellSize=1.0 /res, 
                                                regular=False, 
                                                qdegree = 3
                                        )

#meshbox = uw.meshing.StructuredQuadBox(minCoords=(0.0, 0.0), maxCoords=(boxLength, boxHeight),  elementRes=(res,res))
# Out:
# Processing gmsh file .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh
# Mesh saved to .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh.h5

# %% [markdown]
# ## Reference values
# The temperature, T, pressure, p, and density are expressed as a sum of a reference state and a departure from this state:
#
# \begin{aligned}
# T = \bar T + T'\space \; \; \; p = \bar p + p'  \; \; \;  \rho = \bar \rho (\bar T, \bar p) + \rho'
# \end{aligned}
#
# Where the overbarred quantities are the reference states, and the primed quantities are the perturbations. The reference states are temporally static and varies with depth, z.

# %%
# the non-dimensionalized reference states are defined here
# In King et al and Davies et al, the reference states are set such that z = 0 is the top surface 
# and z = 1 is the lower surface
# For our case, z = 0 is the bottom, while z = 1 is the top. Because of this, we use 1 - z as coordinates
# for the reference values 

x, z = meshbox.X
rhoBar     = rho0*sympy.exp(Di*(1 - z)/gammaR)        
temp_bar    = Ts*(sympy.exp(Di*(1 - z)) - 1)            # Ts is the non-dimensionalized surface temperature

# %%
# visualise the mesh if in a notebook / serial

if uw.mpi.size == 1:
    import numpy as np
    import pyvista as pv
    import vtk

    pv.global_theme.background = "white"
    pv.global_theme.window_size = [750, 750]
    pv.global_theme.antialiasing = True
    pv.global_theme.jupyter_backend = "panel"
    pv.global_theme.smooth_shading = True
    pv.global_theme.camera["viewup"] = [0.0, 1.0, 0.0]
    pv.global_theme.camera["position"] = [0.0, 0.0, -5.0]
    pv.global_theme.show_edges = True
    pv.global_theme.axes.show = True

    meshbox.vtk("tmp_box_mesh.vtk")
    pvmesh = pv.read("tmp_box_mesh.vtk")
    pl = pv.Plotter()

    # pl.add_mesh(pvmesh,'Black', 'wireframe', opacity=0.5)
    pl.add_mesh(pvmesh, edge_color="Black", show_edges=True)

    pl.show(cpos="xy")
# Out:
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2500: PyVistaDeprecationWarning: antialising is deprecated.  Please use `anti_aliasing` instead.
#   warnings.warn(
# /Users/jcgraciosa/mambaforge/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2468: PyVistaDeprecationWarning: `anti_aliasing` is now a string or None and must be either "ssaa", "msaa", "fxaa", or None
#   warnings.warn(
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# /var/folders/91/xdyy27357hv1tymzym7xhf5h0000gq/T/ipykernel_35516/1359165157.py:11: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.global_theme.jupyter_backend = "panel"
# BokehModel(combine_events=True, render_bundle={'docs_json': {'8e30cd4a-b556-44a4-a9eb-e57b8cc998ec': {'defs': …

# %%
v_soln = uw.discretisation.MeshVariable("U", meshbox, meshbox.dim, degree=2)
p_soln = uw.discretisation.MeshVariable("P", meshbox, 1, degree=1)
t_soln = uw.discretisation.MeshVariable("T", meshbox, 1, degree=3)

# additional variable for the gradient
dTdZ = uw.discretisation.MeshVariable(r"\partial T/ \partial \Z", 
                                      meshbox, 
                                      1, 
                                      degree = 3) 

# variable containing stress in the z direction
sigma_zz = uw.discretisation.MeshVariable(r"\sigma_{zz}",  
                                        meshbox, 
                                        1, degree=2)


x, z = meshbox.X

# projection object to calculate the gradient along Z
dTdZ_calc = uw.systems.Projection(meshbox, dTdZ)
dTdZ_calc.uw_function = t_soln.sym.diff(z)[0]
dTdZ_calc.smoothing = 1.0e-3
dTdZ_calc.petsc_options.delValue("ksp_monitor")

# %% [markdown]
# ### System set-up (Stokes)
# In the Truncated Anelastic Liquid Approximation, the conservation of mass is expressed as:
# \begin{aligned}
# \nabla \cdot (\bar \rho \vec u) = \nabla \cdot \vec u + \frac{1}{\bar \rho} \vec u \nabla \bar \rho = 0.
# \end{aligned}
# While the conservation of momentum is given as:
# \begin{aligned}
# \nabla \cdot [\eta (\nabla \vec u + \nabla \vec u^T - \frac {2}{3}\nabla \cdot \vec u \bold I)] - \nabla p' - Ra \bar \rho \bar g \bar \alpha (T - \bar T)= 0.
# \end{aligned}
# The deviatoric strain tensor, $\tau$, is:
# \begin{aligned}
# \tau = 2 \eta \dot \epsilon = \eta (\nabla \vec u + \nabla \vec u^T - \frac {2}{3}\nabla \cdot \vec u \bold I)
# \end{aligned}

# %%
# Create Stokes object

stokes = Stokes(
    meshbox,
    velocityField=v_soln,
    pressureField=p_soln,
    solver_name="stokes",
)
''' set-up petsc options here '''
stokes.petsc_options["snes_type"] = "ksponly"
# stokes.petsc_options['pc_type'] = 'lu'
stokes.tolerance = tol
stokes.petsc_options["snes_max_it"] = 1000
# stokes petsc parameters
# stokes.petsc_options["ksp_monitor"] = None


# stokes.petsc_options["snes_atol"] = 1e-6
# stokes.petsc_options["snes_rtol"] = 1e-6

#stokes.petsc_options["ksp_rtol"]  = 1e-5 # reduce tolerance to increase speed

# Set solve options here (or remove default values
# stokes.petsc_options.getAll()

#stokes.petsc_options["snes_rtol"] = 1.0e-6
# stokes.petsc_options["fieldsplit_pressure_ksp_monitor"] = None
# stokes.petsc_options["fieldsplit_velocity_ksp_monitor"] = None
# stokes.petsc_options["fieldsplit_pressure_ksp_rtol"] = 1.0e-6
# stokes.petsc_options["fieldsplit_velocity_ksp_rtol"] = 1.0e-2
# stokes.petsc_options.delValue("pc_use_amat")

# additional term in constitutive equation? 
stokes.constitutive_model = uw.systems.constitutive_models.ViscousFlowModel(meshbox.dim)
stokes.constitutive_model.Parameters.viscosity=viscosity
stokes.saddle_preconditioner = 1.0 / viscosity

# TODO: constitutive equation

# Free-slip boundary conditions
stokes.add_dirichlet_bc((0.0,), "Left", (0,))
stokes.add_dirichlet_bc((0.0,), "Right", (0,))
stokes.add_dirichlet_bc((0.0,), "Top", (1,))
stokes.add_dirichlet_bc((0.0,), "Bottom", (1,))

# NOTE: we set z = 0 to be the top and z = 1 to be bottom
buoyancy_force = Ra * rhoBar * alphaBar * (t_soln.sym[0] - temp_bar) # directed downwards toward z = 0 (surface)
stokes.bodyforce = sympy.Matrix([0, buoyancy_force])

# add terms into the conservation of mass according to the formulation of TALA compressible convection
stokes.PF0 = sympy.Matrix([dot(v_soln.fn, gradient(rhoBar))/rhoBar])
stokes.UF1 = (-2/3)*divergence(v_soln.fn) * sympy.eye(meshbox.dim)

stokes.stokes_problem_description() # FIXME: need to run this?

# %%
# check the equations for the Stokes system
display(stokes._p_f0) # LHS of c.o. mass 
display(stokes._u_f1) # LHS of c.o. momentum
display(stokes._u_f0) # RHS of c.o. momentum / buoyancy force
# Out:
# Matrix([[U_{ 0,0}(N0.x, N0.y) - 0.5*U_{ 1 }(N0.x, N0.y) + U_{ 1,1}(N0.x, N0.y)]])
# Matrix([
# [-P(N0.x, N0.y) + 1.33333333333333*U_{ 0,0}(N0.x, N0.y) - 0.666666666666667*U_{ 1,1}(N0.x, N0.y),                                                     U_{ 0,1}(N0.x, N0.y) + U_{ 1,0}(N0.x, N0.y)],
# [                                                    U_{ 0,1}(N0.x, N0.y) + U_{ 1,0}(N0.x, N0.y), -P(N0.x, N0.y) - 0.666666666666667*U_{ 0,0}(N0.x, N0.y) + 1.33333333333333*U_{ 1,1}(N0.x, N0.y)]])
# Matrix([[0, -16487.2127070013*(T(N0.x, N0.y) + 0.091 - 0.150033635633712*exp(-0.5*N0.y))*exp(-0.5*N0.y)]])

# %% [markdown]
# ### System set-up (Advection-Diffusion)
# In the TALA formulation, the conservation of energy in terms of the total temperature, T, is expressed as:
#
# \begin{aligned}
# \frac{DT}{Dt} - \frac{Di \bar \alpha}{\bar c_p}\vec g \cdot \vec u (T + T_s) = \frac {1} {\bar \rho \bar c_p} \nabla \cdot (\bar k \nabla T) + \frac{Di}{Ra} \frac{1}{\bar \rho \bar c_p} \phi
# \end{aligned}

# %%
# Create adv_diff object

adv_diff = uw.systems.AdvDiffusionSLCN(
    meshbox,
    u_Field=t_soln,
    V_Field=v_soln,
    solver_name="adv_diff",
)

adv_diff.constitutive_model = uw.systems.constitutive_models.DiffusionModel(meshbox.dim)
adv_diff.constitutive_model.Parameters.diffusivity = (k/(rhoBar*cp))

# add source terms based needed for the EBA case

#viscous dissipation term
comp_strainrate = stokes.strainrate -(2/3)*divergence(v_soln.fn) * sympy.eye(meshbox.dim)
visc_diss = 2*viscosity*comp_strainrate.norm()**2

# adiabatic term - g is pointed up so this term is positive
adiab_heat = (Di*alphaBar/cp)*v_soln.sym[1]*(t_soln.sym[0] + Ts)

#term3 = (Di**2/(rhoBar*c_p))*t_soln.sym[0] # FIXME: term not in the Davies formulation

adv_diff.f = (Di/Ra)*(1/(rhoBar*cp))*visc_diss - adiab_heat #- term3 

adv_diff.theta = 0.5

# Dirichlet boundary conditions for temperature
# note that that Top is now the source of heat - deep in the mantle
# z = 0 is the surface 
adv_diff.add_dirichlet_bc(1.0, "Bottom")
adv_diff.add_dirichlet_bc(0.0, "Top")

adv_diff.petsc_options["pc_gamg_agg_nsmooths"] = 5

adv_diff.adv_diff_slcn_problem_description() # need to run this?

# %%
# comp_strainrate = stokes.strainrate -(2/3)*divergence(v_soln.fn) * sympy.eye(meshbox.dim)
# sympy.simplify(comp_strainrate.norm()**2)

# %% [markdown]
# ### Set initial temperature field
#
# The initial temperature field is set to a sinusoidal perturbation.

# %%
import math, sympy

if infile is None:
    pertStrength = 0.1
    deltaTemp = tempMax - tempMin

    with meshbox.access(t_soln):
        t_soln.data[:] = 0.


    with meshbox.access(t_soln):
        for index, coord in enumerate(t_soln.coords):
            # print(index, coord)
            pertCoeff = math.cos( math.pi * coord[0]/boxLength ) * math.sin( math.pi * coord[1]/boxLength )
        
            t_soln.data[index] = tempMin + deltaTemp*(boxHeight - coord[1]) + pertStrength * pertCoeff
            t_soln.data[index] = max(tempMin, min(tempMax, t_soln.data[index]))
else:
    meshbox_prev = uw.meshing.UnstructuredSimplexBox(
                                                            minCoords=(0.0, 0.0), 
                                                            maxCoords=(boxLength, boxHeight), 
                                                            cellSize=1.0/prev_res,
                                                            qdegree = 3,
                                                            regular = False
                                                        )
    
    # T should have high degree for it to converge
    v_soln_prev = uw.discretisation.MeshVariable("U", meshbox_prev, meshbox_prev.dim, degree=2) # degree = 2
    p_soln_prev = uw.discretisation.MeshVariable("P", meshbox_prev, 1, degree=1) # degree = 1
    t_soln_prev = uw.discretisation.MeshVariable("T", meshbox_prev, 1, degree=3) # degree = 3

    v_soln_prev.load_from_h5_plex_vector(infile + '.U.0.h5')
    p_soln_prev.load_from_h5_plex_vector(infile + '.P.0.h5')
    t_soln_prev.load_from_h5_plex_vector(infile + '.T.0.h5')

    with meshbox.access(v_soln, t_soln, p_soln):    
        t_soln.data[:, 0] = uw.function.evaluate(t_soln_prev.sym[0], t_soln.coords)
        p_soln.data[:, 0] = uw.function.evaluate(p_soln_prev.sym[0], p_soln.coords)

        #for velocity, encounters errors when trying to interpolate in the non-zero boundaries of the mesh variables 
        v_coords = deepcopy(v_soln.coords)

        v_soln.data[:] = uw.function.evaluate(v_soln_prev.fn, v_coords)

    del meshbox_prev
    del v_soln_prev
    del p_soln_prev
    del t_soln_prev
# Out:
# Processing gmsh file .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh
# Mesh saved to .meshes/uw_simplexbox_minC(0.0, 0.0)_maxC(1.0, 1.0)_csize0.0625_regFalse.msh.h5

# %% [markdown]
# ### Some plotting and analysis tools

# %%
# check the mesh if in a notebook / serial
# allows you to visualise the mesh and the mesh variable
'''FIXME: change this so it's better'''

def plotFig(meshbox, s_field, v_field, s_field_name, save_fname = None, with_arrows = False, cmap = "coolwarm"): 
    """
    s_field - scalar field - corresponds to colors
    v_field - vector field - usually the velocity - 2 components
    """
    if uw.mpi.size == 1:

        import numpy as np
        import pyvista as pv
        import vtk

        pv.global_theme.background = "white"
        pv.global_theme.window_size = [500, 500]
        pv.global_theme.anti_aliasing = None #"ssaa", "msaa", "fxaa", or None
        #pv.global_theme.jupyter_backend = "panel"
        pv.global_theme.smooth_shading = True

        meshbox.vtk("tmp_box_mesh.vtk")
        pvmesh = pv.read("tmp_box_mesh.vtk")

        velocity = np.zeros((meshbox.data.shape[0], 3))
        velocity[:, 0] = uw.function.evaluate(v_field.sym[0], meshbox.data)
        velocity[:, 1] = uw.function.evaluate(v_field.sym[1], meshbox.data)

        #pvmesh.point_data["V"] = velocity / 10

        points = np.zeros((s_field.coords.shape[0], 3))
        points[:, 0] = s_field.coords[:, 0]
        points[:, 1] = s_field.coords[:, 1]

        point_cloud = pv.PolyData(points)

        with meshbox.access():
            point_cloud.point_data[s_field_name] = uw.function.evaluate(s_field.fn, points[:, 0:2])

        skip = 2
        num_row = len(meshbox._centroids[::skip, 0])

        cpoints = np.zeros((num_row, 3))
        cpoints[:, 0] = meshbox._centroids[::skip, 0]
        cpoints[:, 1] = meshbox._centroids[::skip, 1]

        cpoint_cloud = pv.PolyData(cpoints)

        # pvstream = pvmesh.streamlines_from_source(
        #     cpoint_cloud,
        #     vectors="V",
        #     integrator_type=2,
        #     integration_direction="forward",
        #     compute_vorticity=False,
        #     max_steps=1000,
        #     surface_streamlines=True,
        # )
 
        pl = pv.Plotter()

        with meshbox.access():
            skip = 2
        
            num_row = len(v_field.coords[::skip, 0:2])

            arrow_loc = np.zeros((num_row, 3))
            arrow_loc[:, 0:2] = v_field.coords[::skip, 0:2]

            arrow_length = np.zeros((num_row, 3))
            arrow_length[:, 0] = v_field.data[::skip, 0]
            arrow_length[:, 1] = v_field.data[::skip, 1]

        pl = pv.Plotter()

        #pl.add_mesh(pvmesh,'Gray', 'wireframe')

        pl.add_mesh(
            pvmesh, cmap=cmap, edge_color="Black",
            show_edges=True, use_transparency=False, opacity=0.1,
        )

      
        if with_arrows:
            pl.add_arrows(arrow_loc, arrow_length, mag=0.04, opacity=0.8)
        else:
            pl.add_points(point_cloud, cmap=cmap, point_size=18, opacity=0.8)


        # pl.add_mesh(pvstream, opacity=0.5)
        # pl.add_arrows(arrow_loc2, arrow_length2, mag=1.0e-1)

        # pl.add_points(pdata)

        pl.show(cpos="xy", jupyter_backend = "panel")

        if save_fname is not None:
            #pl.save_graphic(save_fname, dpi = 300)
            pl.image_scale = 3
            pl.screenshot(save_fname) 

        pvmesh.clear_data()
        pvmesh.clear_point_data()
        
        
plotFig(meshbox, t_soln, v_soln, "T", save_fname = None, with_arrows = False, cmap = "coolwarm")
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'a58252b5-eef1-449f-8892-d4957f4ee17e': {'defs': …

# %% [markdown]
# #### RMS velocity
# The root mean squared velocity, $v_{rms}$, is defined as:
#
#
# \begin{aligned}
# v_{rms}  =  \sqrt{ \frac{ \int_V (\mathbf{v}.\mathbf{v}) dV } {\int_V dV} }
# \end{aligned}
#
# where $\bf{v}$ denotes the velocity field and $V$ is the volume of the box.

# %%
# underworld3 function for calculating the rms velocity 

def v_rms(mesh = meshbox, v_solution = v_soln): 
    # v_soln must be a variable of mesh
    v_rms = math.sqrt(uw.maths.Integral(mesh, v_solution.fn.dot(v_solution.fn)).evaluate())
    return v_rms

#print(f'initial v_rms = {v_rms()}')

# %% [markdown]
# #### Surface integrals
# Since there is no uw3 function yet to calculate the surface integral, we define one.  \
# The surface integral of a function, $f_i(\mathbf{x})$, is approximated as:
#
# \begin{aligned}
# F_i = \int_V f_i(\mathbf{x}) S(\mathbf{x})  dV
# \end{aligned}
#
# With $S(\mathbf{x})$ defined as an un-normalized Gaussian function with the maximum at $z = a$  - the surface we want to evaluate the integral in (e.g. z = 1 for surface integral at the top surface):
#
# \begin{aligned}
# S(\mathbf{x}) = exp \left( \frac{-(z-a)^2}{2\sigma ^2} \right)
# \end{aligned}
#
# In addition, the full-width at half maximum is set to 1/res so the standard deviation, $\sigma$ is calculated as:
#
# \begin{aligned}
# \sigma = \frac{1}{2}\frac{1}{\sqrt{ 2 log 2}}\frac{1}{res}
# \end{aligned}

# %%
# function for calculating the surface integral 
def surface_integral(mesh, uw_function, mask_fn):

    calculator = uw.maths.Integral(mesh, uw_function * mask_fn)
    value = calculator.evaluate()

    calculator.fn = mask_fn
    norm = calculator.evaluate()

    integral = value / norm

    return integral

''' set-up surface expressions for calculating Nu number '''
sdev = 0.5*(1/math.sqrt(2*math.log(2)))*(1/res) 

up_surface_defn_fn = sympy.exp(-((z - 1)**2)/(2*sdev**2)) # at z = 1
lw_surface_defn_fn = sympy.exp(-(z**2)/(2*sdev**2)) # at z = 0

# %%
# functions for calculating the viscous dissipation and adiabatic heating integrals 
# used for checking since they should be equal
visc_diss_int_calc = uw.maths.Integral(meshbox, visc_diss)
adiab_heat_int_calc = uw.maths.Integral(meshbox, adiab_heat)

# %% [markdown]
# ### Main simulation loop

# %%
t_step = 0
time = 0.

timeVal =  np.zeros(nsteps)*np.nan
vrmsVal =  np.zeros(nsteps)*np.nan
NuVal =  np.zeros(nsteps)*np.nan
viscDissVal = np.zeros(nsteps)*np.nan
adiabHeatVal = np.zeros(nsteps)*np.nan

# %%
#### Convection model / update in time


# NOTE: There is a strange interaction here between the solvers if the zero_guess is set to False


while t_step < nsteps:
    vrmsVal[t_step] = v_rms()
    timeVal[t_step] = time

    stokes.solve(zero_init_guess=True) # originally True
    delta_t = 0.5 * stokes.estimate_dt()
    adv_diff.solve(timestep=delta_t, zero_init_guess=False) # originally False

    # calculate Nusselt number
    # for this case, top surface is set to 1, while bottom is set to 0
    dTdZ_calc.solve()
    up_int = surface_integral(meshbox, dTdZ.sym[0], up_surface_defn_fn)
    lw_int = surface_integral(meshbox, t_soln.sym[0], lw_surface_defn_fn)

    Nu = -up_int/lw_int

    NuVal[t_step] = -up_int/lw_int

    # calculate the integrals of viscous dissipation and adiabatic heating
    viscDissVal[t_step] = visc_diss_int_calc.evaluate()
    adiabHeatVal[t_step] = adiab_heat_int_calc.evaluate()

    # stats then loop
    tstats = t_soln.stats()

    if uw.mpi.rank == 0:
        print("Timestep {}, dt {}".format(t_step, delta_t))
            
        print(f't_rms = {t_soln.stats()[6]}, v_rms = {vrmsVal[t_step]}, Nu = {NuVal[t_step]}')

        ''' save mesh variables together with mesh '''
        if t_step % save_every == 0:
            print("Saving checkpoint for time step: ", t_step)
            meshbox.write_timestep_xdmf(filename = outfile, meshVars=[v_soln, p_soln, t_soln, dTdZ, sigma_zz], index=0)

    # early stopping criterion
    if t_step > 1 and abs((NuVal[t_step] - NuVal[t_step - 1])/NuVal[t_step]) < epsilon_lr:
        break

    t_step += 1
    time   += delta_t

# save final mesh variables in the run 
os.makedirs("../TALA_meshes", exist_ok = True)

expt_name = "TALA_Ra1e4_res" + str(res)
savefile = "{}_ts{}.h5".format(expt_name,t_step)

# save final mesh variables in the run 
meshbox.write_timestep_xdmf(filename = outfile, meshVars=[v_soln, p_soln, t_soln, dTdZ, sigma_zz], index=0)
# Out:
#   0 SNES Function norm 243.402
#   1 SNES Function norm 0.0119682
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000894098
#   1 SNES Function norm 1.12915e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292047
#   1 SNES Function norm 1.55924e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 0, dt 6.469504533213571e-05
# t_rms = 0.5669234628143885, v_rms = 54.023103235836, Nu = 2.4381078709386284
# Saving checkpoint for time step:  0
# Saving mesh file
#   0 SNES Function norm 243.402
#   1 SNES Function norm 0.012609
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000865036
#   1 SNES Function norm 1.95362e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292046
#   1 SNES Function norm 1.55921e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 1, dt 6.470536715327817e-05
# t_rms = 0.5669239472522898, v_rms = 54.024212964737934, Nu = 2.4380885070526923
#   0 SNES Function norm 243.403
#   1 SNES Function norm 0.0209349
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000852171
#   1 SNES Function norm 1.89347e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292044
#   1 SNES Function norm 1.55918e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 2, dt 6.470660581524576e-05
# t_rms = 0.5669244791125863, v_rms = 54.02471277125755, Nu = 2.4380705464072
#   0 SNES Function norm 243.403
#   1 SNES Function norm 0.0776314
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00079902
#   1 SNES Function norm 1.11516e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292043
#   1 SNES Function norm 1.55915e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 3, dt 6.470783024856226e-05
# t_rms = 0.5669253893427764, v_rms = 54.025785182582055, Nu = 2.4380603820887363
#   0 SNES Function norm 243.404
#   1 SNES Function norm 0.00182225
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000853137
#   1 SNES Function norm 2.05099e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292042
#   1 SNES Function norm 1.55911e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 4, dt 6.470169269121658e-05
# t_rms = 0.5669259179997357, v_rms = 54.02388591738051, Nu = 2.4380377229534416
#   0 SNES Function norm 243.404
#   1 SNES Function norm 0.000346408
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000839699
#   1 SNES Function norm 1.93397e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029204
#   1 SNES Function norm 1.55908e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 5, dt 6.469884399488025e-05
# t_rms = 0.5669264531713301, v_rms = 54.02666514249329, Nu = 2.43801903352601
#   0 SNES Function norm 243.404
#   1 SNES Function norm 0.00867048
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000828114
#   1 SNES Function norm 1.88968e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292039
#   1 SNES Function norm 1.55905e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 6, dt 6.469907048960356e-05
# t_rms = 0.5669269850847175, v_rms = 54.027384826608774, Nu = 2.438000187168648
#   0 SNES Function norm 243.405
#   1 SNES Function norm 0.00899174
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000820169
#   1 SNES Function norm 1.83877e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292038
#   1 SNES Function norm 1.55902e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 7, dt 6.469724445515636e-05
# t_rms = 0.5669275063633187, v_rms = 54.02813976931149, Nu = 2.4379833508230355
#   0 SNES Function norm 243.405
#   1 SNES Function norm 0.0528735
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000861006
#   1 SNES Function norm 1.90223e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292037
#   1 SNES Function norm 1.55898e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 8, dt 6.471057897845776e-05
# t_rms = 0.5669279260970316, v_rms = 54.028884370634735, Nu = 2.437964037565036
#   0 SNES Function norm 243.405
#   1 SNES Function norm 0.00036098
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000820685
#   1 SNES Function norm 1.87496e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292036
#   1 SNES Function norm 1.55895e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 9, dt 6.469517837755631e-05
# t_rms = 0.5669284495810591, v_rms = 54.03083292673091, Nu = 2.437946145675337
#   0 SNES Function norm 243.406
#   1 SNES Function norm 0.00185504
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000800037
#   1 SNES Function norm 1.79433e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292035
#   1 SNES Function norm 1.55893e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 10, dt 6.469267970069385e-05
# t_rms = 0.5669289725098606, v_rms = 54.03055121029625, Nu = 2.437933085161803
# Saving checkpoint for time step:  10
# Saving mesh file
#   0 SNES Function norm 243.406
#   1 SNES Function norm 0.00500335
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000778569
#   1 SNES Function norm 1.85228e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292034
#   1 SNES Function norm 1.55889e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 11, dt 6.469914601593061e-05
# t_rms = 0.5669294697956593, v_rms = 54.03128087557435, Nu = 2.4379109335048237
#   0 SNES Function norm 243.407
#   1 SNES Function norm 0.00117105
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000783129
#   1 SNES Function norm 1.76621e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292033
#   1 SNES Function norm 1.55886e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 12, dt 6.469277529101262e-05
# t_rms = 0.5669299745067888, v_rms = 54.03219622690782, Nu = 2.4378964508089194
#   0 SNES Function norm 243.407
#   1 SNES Function norm 0.00218743
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000777714
#   1 SNES Function norm 1.72168e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292032
#   1 SNES Function norm 1.55884e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 13, dt 6.468992179778566e-05
# t_rms = 0.5669304853515047, v_rms = 54.03285983439117, Nu = 2.4378853587870424
#   0 SNES Function norm 243.407
#   1 SNES Function norm 0.0251642
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000769898
#   1 SNES Function norm 1.59404e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292032
#   1 SNES Function norm 1.55881e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 14, dt 6.470071998204493e-05
# t_rms = 0.5669309416514623, v_rms = 54.033625430813785, Nu = 2.437875117214961
#   0 SNES Function norm 243.408
#   1 SNES Function norm 0.0381508
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000814645
#   1 SNES Function norm 1.78769e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292031
#   1 SNES Function norm 1.55879e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 15, dt 6.469573250344827e-05
# t_rms = 0.5669312562116448, v_rms = 54.03466375599857, Nu = 2.437868342908767
#   0 SNES Function norm 243.408
#   1 SNES Function norm 0.0014784
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000755593
#   1 SNES Function norm 1.6541e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029203
#   1 SNES Function norm 1.55876e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 16, dt 6.468844193167477e-05
# t_rms = 0.5669317541982074, v_rms = 54.035724387490866, Nu = 2.4378540402675686
#   0 SNES Function norm 243.408
#   1 SNES Function norm 0.0443409
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000809118
#   1 SNES Function norm 1.80119e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029203
#   1 SNES Function norm 1.55874e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 17, dt 6.469426049375604e-05
# t_rms = 0.5669320567727969, v_rms = 54.036236894910516, Nu = 2.4378470046215406
#   0 SNES Function norm 243.408
#   1 SNES Function norm 0.0207184
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00076015
#   1 SNES Function norm 1.63701e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292029
#   1 SNES Function norm 1.55871e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 18, dt 6.46950036493944e-05
# t_rms = 0.5669324683752065, v_rms = 54.03768868617662, Nu = 2.4378323083903513
#   0 SNES Function norm 243.409
#   1 SNES Function norm 0.0282644
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000761295
#   1 SNES Function norm 1.65522e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292029
#   1 SNES Function norm 1.55869e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 19, dt 6.469270792240792e-05
# t_rms = 0.5669328697123343, v_rms = 54.03848357696728, Nu = 2.437830055588218
#   0 SNES Function norm 243.409
#   1 SNES Function norm 0.00908663
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000735512
#   1 SNES Function norm 1.57428e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292028
#   1 SNES Function norm 1.55866e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 20, dt 6.468256883472562e-05
# t_rms = 0.5669333574329786, v_rms = 54.03890997992985, Nu = 2.4378205660260517
# Saving checkpoint for time step:  20
# Saving mesh file
#   0 SNES Function norm 243.409
#   1 SNES Function norm 0.0423462
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000745348
#   1 SNES Function norm 1.56175e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292028
#   1 SNES Function norm 1.55864e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 21, dt 6.470810333896686e-05
# t_rms = 0.566933745364478, v_rms = 54.039715867211434, Nu = 2.437814935087382
#   0 SNES Function norm 243.41
#   1 SNES Function norm 0.00891456
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000729141
#   1 SNES Function norm 1.5957e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.55862e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 22, dt 6.468247786212619e-05
# t_rms = 0.5669342234921316, v_rms = 54.04083334373269, Nu = 2.4378009162393885
#   0 SNES Function norm 243.41
#   1 SNES Function norm 0.0379331
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000830449
#   1 SNES Function norm 1.12565e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.5586e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 23, dt 6.466498801517533e-05
# t_rms = 0.5669347295805687, v_rms = 54.04149432546013, Nu = 2.4378089403798042
#   0 SNES Function norm 243.41
#   1 SNES Function norm 0.0233954
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000776165
#   1 SNES Function norm 1.8168e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.55858e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 24, dt 6.467786648053663e-05
# t_rms = 0.5669351526524862, v_rms = 54.0424425652886, Nu = 2.4378088476236703
#   0 SNES Function norm 243.41
#   1 SNES Function norm 0.0367637
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000666325
#   1 SNES Function norm 7.54792e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.55855e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 25, dt 6.466227101372383e-05
# t_rms = 0.5669357428851143, v_rms = 54.04326720878636, Nu = 2.4378024470184743
#   0 SNES Function norm 243.411
#   1 SNES Function norm 0.00179768
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000701508
#   1 SNES Function norm 1.53213e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.55854e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 26, dt 6.467626542063756e-05
# t_rms = 0.5669362025713455, v_rms = 54.04486077495025, Nu = 2.43779886469791
#   0 SNES Function norm 243.411
#   1 SNES Function norm 0.000724994
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000688177
#   1 SNES Function norm 1.45992e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.55851e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 27, dt 6.467723890198686e-05
# t_rms = 0.5669366517237113, v_rms = 54.04494429708936, Nu = 2.4377904188887833
#   0 SNES Function norm 243.411
#   1 SNES Function norm 0.00181938
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000679293
#   1 SNES Function norm 1.48895e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.55849e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 28, dt 6.467811605400584e-05
# t_rms = 0.5669370897410921, v_rms = 54.045842357109734, Nu = 2.4377795475169113
#   0 SNES Function norm 243.412
#   1 SNES Function norm 0.00903289
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000675599
#   1 SNES Function norm 1.44879e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55847e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 29, dt 6.467796955706155e-05
# t_rms = 0.5669375426527754, v_rms = 54.04670635243089, Nu = 2.437771916728276
#   0 SNES Function norm 243.412
#   1 SNES Function norm 0.0208294
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000691323
#   1 SNES Function norm 1.4345e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55845e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 30, dt 6.468283863142426e-05
# t_rms = 0.5669379953178124, v_rms = 54.04770393853607, Nu = 2.4377676402987216
# Saving checkpoint for time step:  30
# Saving mesh file
#   0 SNES Function norm 243.412
#   1 SNES Function norm 0.0941458
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000947047
#   1 SNES Function norm 1.70292e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55838e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 31, dt 6.47247596090046e-05
# t_rms = 0.566938326031712, v_rms = 54.04898665476963, Nu = 2.4377212817463607
#   0 SNES Function norm 243.412
#   1 SNES Function norm 0.0525751
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000746214
#   1 SNES Function norm 1.20361e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55837e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 32, dt 6.464962817402205e-05
# t_rms = 0.5669388750371608, v_rms = 54.04884083391629, Nu = 2.4377309711728725
#   0 SNES Function norm 243.413
#   1 SNES Function norm 0.00182252
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000689174
#   1 SNES Function norm 8.2473e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55836e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 33, dt 6.466971737444982e-05
# t_rms = 0.5669393067256355, v_rms = 54.04980169205667, Nu = 2.437731646230608
#   0 SNES Function norm 243.413
#   1 SNES Function norm 0.0214259
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000636157
#   1 SNES Function norm 6.47656e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55834e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 34, dt 6.466614277895021e-05
# t_rms = 0.5669397516499983, v_rms = 54.050588710632475, Nu = 2.437725965157708
#   0 SNES Function norm 243.413
#   1 SNES Function norm 0.000153476
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000659537
#   1 SNES Function norm 6.66535e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55833e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 35, dt 6.466965688577223e-05
# t_rms = 0.5669401709826847, v_rms = 54.0515834063482, Nu = 2.437722948237384
#   0 SNES Function norm 243.414
#   1 SNES Function norm 0.0036563
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00064491
#   1 SNES Function norm 6.69744e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55831e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 36, dt 6.467233085527657e-05
# t_rms = 0.5669405723319205, v_rms = 54.05231730821796, Nu = 2.437714423584242
#   0 SNES Function norm 243.414
#   1 SNES Function norm 0.00908708
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000644291
#   1 SNES Function norm 1.36388e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55829e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 37, dt 6.466941848594441e-05
# t_rms = 0.5669409769337345, v_rms = 54.0532294846977, Nu = 2.4377092456871967
#   0 SNES Function norm 243.414
#   1 SNES Function norm 0.00951138
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000659917
#   1 SNES Function norm 6.87908e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55828e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 38, dt 6.466904245483687e-05
# t_rms = 0.5669413938443358, v_rms = 54.05403395719444, Nu = 2.4377100949533603
#   0 SNES Function norm 243.414
#   1 SNES Function norm 0.000847664
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000643823
#   1 SNES Function norm 6.44818e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55827e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 39, dt 6.466601712429219e-05
# t_rms = 0.5669417955456282, v_rms = 54.05486629025515, Nu = 2.4377072035893352
#   0 SNES Function norm 243.414
#   1 SNES Function norm 0.00908195
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000652495
#   1 SNES Function norm 6.80141e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292024
#   1 SNES Function norm 1.55826e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 40, dt 6.466330714960204e-05
# t_rms = 0.5669421979914879, v_rms = 54.05568410625418, Nu = 2.4377083244543645
# Saving checkpoint for time step:  40
# Saving mesh file
#   0 SNES Function norm 243.415
#   1 SNES Function norm 0.0222147
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000702083
#   1 SNES Function norm 7.47467e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55825e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 41, dt 6.468425621290017e-05
# t_rms = 0.5669425351909756, v_rms = 54.05650975865334, Nu = 2.4377131533546192
#   0 SNES Function norm 243.415
#   1 SNES Function norm 0.0258394
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000667548
#   1 SNES Function norm 7.4438e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55823e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 42, dt 6.467074231328375e-05
# t_rms = 0.5669428351000394, v_rms = 54.05782434324369, Nu = 2.4377060271418305
#   0 SNES Function norm 243.415
#   1 SNES Function norm 0.00227637
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000624999
#   1 SNES Function norm 6.69934e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55822e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 43, dt 6.466341833922337e-05
# t_rms = 0.5669432204459803, v_rms = 54.05860864351996, Nu = 2.4377012172125148
#   0 SNES Function norm 243.415
#   1 SNES Function norm 0.0105229
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000637927
#   1 SNES Function norm 6.52983e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292025
#   1 SNES Function norm 1.55821e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 44, dt 6.464325713838373e-05
# t_rms = 0.5669436839429487, v_rms = 54.0592109109857, Nu = 2.4377016527660946
#   0 SNES Function norm 243.415
#   1 SNES Function norm 0.0016387
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000654025
#   1 SNES Function norm 6.89177e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.5582e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 45, dt 6.465921851640216e-05
# t_rms = 0.5669440649616558, v_rms = 54.0602074287406, Nu = 2.437705175132075
#   0 SNES Function norm 243.416
#   1 SNES Function norm 0.00182677
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00063988
#   1 SNES Function norm 6.70856e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.55819e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 46, dt 6.465666759261144e-05
# t_rms = 0.5669444537090175, v_rms = 54.060862550329816, Nu = 2.4377082779625057
#   0 SNES Function norm 243.416
#   1 SNES Function norm 0.000809906
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000631547
#   1 SNES Function norm 6.35153e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292026
#   1 SNES Function norm 1.55818e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 47, dt 6.465782768221732e-05
# t_rms = 0.5669448251207726, v_rms = 54.061690739614754, Nu = 2.437709577827651
#   0 SNES Function norm 243.416
#   1 SNES Function norm 0.000480565
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000627625
#   1 SNES Function norm 6.2643e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.55817e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 48, dt 6.465640512221209e-05
# t_rms = 0.566945199038913, v_rms = 54.06255186263837, Nu = 2.4377108756443002
#   0 SNES Function norm 243.416
#   1 SNES Function norm 0.00365347
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000646067
#   1 SNES Function norm 7.30429e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292027
#   1 SNES Function norm 1.55816e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 49, dt 6.465205993145993e-05
# t_rms = 0.5669455803040627, v_rms = 54.063419171648036, Nu = 2.437717404366727
#   0 SNES Function norm 243.416
#   1 SNES Function norm 0.00179354
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000638085
#   1 SNES Function norm 6.73925e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292028
#   1 SNES Function norm 1.55816e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 50, dt 6.465269756878301e-05
# t_rms = 0.5669459524035382, v_rms = 54.064192036859026, Nu = 2.437721610053656
# Saving checkpoint for time step:  50
# Saving mesh file
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.029551
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000676405
#   1 SNES Function norm 8.05242e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292028
#   1 SNES Function norm 1.55815e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 51, dt 6.465502645779175e-05
# t_rms = 0.5669463660377801, v_rms = 54.06508849655541, Nu = 2.437730467233697
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00202933
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000614926
#   1 SNES Function norm 6.30011e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292029
#   1 SNES Function norm 1.55814e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 52, dt 6.46543514018156e-05
# t_rms = 0.5669467160961753, v_rms = 54.06647875929394, Nu = 2.437729887517542
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00909289
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000614108
#   1 SNES Function norm 6.11158e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292029
#   1 SNES Function norm 1.55813e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 53, dt 6.465401839674579e-05
# t_rms = 0.5669470520517071, v_rms = 54.06688618950674, Nu = 2.437730156602313
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.000500623
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000615911
#   1 SNES Function norm 6.20072e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029203
#   1 SNES Function norm 1.55812e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 54, dt 6.465083395844931e-05
# t_rms = 0.5669474017672299, v_rms = 54.06767745476966, Nu = 2.4377325646214407
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00652049
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000633647
#   1 SNES Function norm 6.8143e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029203
#   1 SNES Function norm 1.55811e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 55, dt 6.464749659319845e-05
# t_rms = 0.5669477762757241, v_rms = 54.06848787606506, Nu = 2.4377401765002036
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.000444686
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000621551
#   1 SNES Function norm 6.39525e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292031
#   1 SNES Function norm 1.55811e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 56, dt 6.464883706740008e-05
# t_rms = 0.5669481161237555, v_rms = 54.06937375792529, Nu = 2.4377435654098196
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.00193355
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000625486
#   1 SNES Function norm 6.61958e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292031
#   1 SNES Function norm 1.5581e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 57, dt 6.46458568642074e-05
# t_rms = 0.5669484612486133, v_rms = 54.07014624498175, Nu = 2.437749922533052
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0158095
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000656741
#   1 SNES Function norm 7.06696e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292032
#   1 SNES Function norm 1.5581e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 58, dt 6.465082717795408e-05
# t_rms = 0.5669488143747237, v_rms = 54.07095584378774, Nu = 2.4377583526001714
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0093819
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000625177
#   1 SNES Function norm 7.08855e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292033
#   1 SNES Function norm 1.5581e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 59, dt 6.464212785190861e-05
# t_rms = 0.5669491612284913, v_rms = 54.07231708835315, Nu = 2.4377661920902325
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0371713
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000628036
#   1 SNES Function norm 6.72435e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292034
#   1 SNES Function norm 1.55809e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 60, dt 6.464609611565611e-05
# t_rms = 0.566949511387693, v_rms = 54.07261831793848, Nu = 2.437771929825105
# Saving checkpoint for time step:  60
# Saving mesh file
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0321535
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000648772
#   1 SNES Function norm 8.05859e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292034
#   1 SNES Function norm 1.55808e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 61, dt 6.464023315195871e-05
# t_rms = 0.5669500859762325, v_rms = 54.073854868501215, Nu = 2.4377824936044594
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0129345
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000646636
#   1 SNES Function norm 7.20265e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292035
#   1 SNES Function norm 1.55808e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 62, dt 6.464531099321926e-05
# t_rms = 0.566950428708856, v_rms = 54.07422958755812, Nu = 2.437790796232853
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.000852372
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000608703
#   1 SNES Function norm 6.38898e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292036
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 63, dt 6.46420348219996e-05
# t_rms = 0.566950742659267, v_rms = 54.07529560656979, Nu = 2.437795160289129
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.00929317
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00062601
#   1 SNES Function norm 6.90667e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292037
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 64, dt 6.463779687339958e-05
# t_rms = 0.5669510626826018, v_rms = 54.075960510607764, Nu = 2.4378041263764727
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.00012953
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000618589
#   1 SNES Function norm 6.56238e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292037
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 65, dt 6.464010937701758e-05
# t_rms = 0.5669513671593304, v_rms = 54.0767319123107, Nu = 2.437809914003251
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.000706203
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000611688
#   1 SNES Function norm 6.35575e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292038
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 66, dt 6.463926797274846e-05
# t_rms = 0.566951669383142, v_rms = 54.07757982071618, Nu = 2.4378155690886127
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.0199558
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000656623
#   1 SNES Function norm 7.47824e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292039
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 67, dt 6.463924752815744e-05
# t_rms = 0.5669518692592312, v_rms = 54.07838481450583, Nu = 2.4378259648530705
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.0774431
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000545302
#   1 SNES Function norm 7.37199e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029204
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 68, dt 6.462663522597646e-05
# t_rms = 0.5669524228609549, v_rms = 54.07922219933703, Nu = 2.4378336313255824
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.0208823
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000719625
#   1 SNES Function norm 8.33138e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292041
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 69, dt 6.46418475490857e-05
# t_rms = 0.5669526194262768, v_rms = 54.078492031136065, Nu = 2.4378459305479785
#   0 SNES Function norm 243.419
#   1 SNES Function norm 0.0504411
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000741289
#   1 SNES Function norm 1.17845e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292042
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 70, dt 6.460489703136932e-05
# t_rms = 0.5669534417941379, v_rms = 54.08118542694547, Nu = 2.4378748361886706
# Saving checkpoint for time step:  70
# Saving mesh file
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00907209
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000676717
#   1 SNES Function norm 8.51434e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292043
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 71, dt 6.46362664423602e-05
# t_rms = 0.5669537131059422, v_rms = 54.0809135840061, Nu = 2.4378816496170117
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.023424
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000579327
#   1 SNES Function norm 6.3866e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292044
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 72, dt 6.463041732138727e-05
# t_rms = 0.5669539923882964, v_rms = 54.082276485194924, Nu = 2.437884174664464
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.016837
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000684879
#   1 SNES Function norm 7.52752e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292045
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 73, dt 6.464296117240008e-05
# t_rms = 0.5669542275284849, v_rms = 54.08289823139814, Nu = 2.437896719174816
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00206704
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000593775
#   1 SNES Function norm 6.55019e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292046
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 74, dt 6.462991799285806e-05
# t_rms = 0.566954506362968, v_rms = 54.08396746720269, Nu = 2.437905145332082
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00918057
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000607167
#   1 SNES Function norm 6.62388e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292046
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 75, dt 6.4634120172079e-05
# t_rms = 0.5669547665748113, v_rms = 54.084565036328364, Nu = 2.437908439111527
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00909758
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000605277
#   1 SNES Function norm 6.68465e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292047
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 76, dt 6.46278946438095e-05
# t_rms = 0.5669550442487763, v_rms = 54.08538608695547, Nu = 2.4379180764267283
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00367836
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000607054
#   1 SNES Function norm 7.0598e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292048
#   1 SNES Function norm 1.55805e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 77, dt 6.463291117859244e-05
# t_rms = 0.566955294789848, v_rms = 54.08607485704439, Nu = 2.437920522742296
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.0525784
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000839747
#   1 SNES Function norm 1.20649e-08
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029205
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 78, dt 6.464240239113878e-05
# t_rms = 0.5669553253270968, v_rms = 54.08691786895242, Nu = 2.4379458631201536
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00183547
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000581284
#   1 SNES Function norm 7.35009e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292051
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 79, dt 6.462540238447582e-05
# t_rms = 0.5669555986480621, v_rms = 54.088447387395405, Nu = 2.4379528590297372
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.0026734
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000619205
#   1 SNES Function norm 7.103e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292052
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 80, dt 6.462363698517796e-05
# t_rms = 0.5669558666794426, v_rms = 54.08851542951261, Nu = 2.437964539154459
# Saving checkpoint for time step:  80
# Saving mesh file
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00199287
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000609745
#   1 SNES Function norm 7.00938e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292053
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 81, dt 6.462764907629425e-05
# t_rms = 0.5669561095715302, v_rms = 54.08923863753107, Nu = 2.437970535845442
#   0 SNES Function norm 243.42
#   1 SNES Function norm 0.00890576
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000601296
#   1 SNES Function norm 6.52579e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292054
#   1 SNES Function norm 1.55806e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 82, dt 6.462500077657099e-05
# t_rms = 0.5669563579702729, v_rms = 54.09002721495242, Nu = 2.437978970724183
#   0 SNES Function norm 243.421
#   1 SNES Function norm 0.00909037
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000610225
#   1 SNES Function norm 6.89473e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292055
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 83, dt 6.462190288442187e-05
# t_rms = 0.5669566135965849, v_rms = 54.09073189229087, Nu = 2.43799084076212
#   0 SNES Function norm 243.421
#   1 SNES Function norm 0.00250774
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00060417
#   1 SNES Function norm 6.84456e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292056
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 84, dt 6.462571396880371e-05
# t_rms = 0.566956855380303, v_rms = 54.09142585732135, Nu = 2.437996325309161
#   0 SNES Function norm 243.421
#   1 SNES Function norm 0.00396954
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.00059506
#   1 SNES Function norm 6.64527e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292057
#   1 SNES Function norm 1.55807e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 85, dt 6.462417112320042e-05
# ...
#   0 SNES Function norm 0.0292236
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 322, dt 6.459596165305698e-05
# t_rms = 0.5669795117230396, v_rms = 54.12072605416498, Nu = 2.4403213864593063
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00965158
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000216457
#   1 SNES Function norm 3.9175e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292236
#   1 SNES Function norm 1.56008e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 323, dt 6.459176681496858e-05
# t_rms = 0.5669795739703267, v_rms = 54.120793218705536, Nu = 2.4403114516912527
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00196075
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000156434
#   1 SNES Function norm 2.37124e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292236
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 324, dt 6.458651427630125e-05
# t_rms = 0.5669796608345609, v_rms = 54.12051686072071, Nu = 2.4403109738554996
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00235405
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000145783
#   1 SNES Function norm 1.87108e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292235
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 325, dt 6.458678507934194e-05
# t_rms = 0.5669797464279566, v_rms = 54.1202391746019, Nu = 2.4403101220253145
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00199705
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000143789
#   1 SNES Function norm 1.70504e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292235
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 326, dt 6.458701859162193e-05
# t_rms = 0.5669798299589911, v_rms = 54.120059565919014, Nu = 2.440309673468087
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00191037
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000143228
#   1 SNES Function norm 1.61587e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292235
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 327, dt 6.458687249280592e-05
# t_rms = 0.5669799161181395, v_rms = 54.119887884185935, Nu = 2.4403095297913215
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00186332
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000141356
#   1 SNES Function norm 1.56341e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292235
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 328, dt 6.458706060380051e-05
# t_rms = 0.5669800006224772, v_rms = 54.119733324463354, Nu = 2.4403096015822694
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00868137
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000147985
#   1 SNES Function norm 1.95986e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292235
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 329, dt 6.458924611201896e-05
# t_rms = 0.5669800786408106, v_rms = 54.11957003644782, Nu = 2.440306633476806
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00056976
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000153102
#   1 SNES Function norm 2.04487e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292234
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 330, dt 6.458933749121966e-05
# t_rms = 0.5669801576167379, v_rms = 54.11943627593022, Nu = 2.4403035455642765
# Saving checkpoint for time step:  330
# Saving mesh file
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00191849
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000145671
#   1 SNES Function norm 1.77197e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292234
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 331, dt 6.458793470377008e-05
# t_rms = 0.5669802431409497, v_rms = 54.1192734703086, Nu = 2.440302928337761
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00374387
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.0001477
#   1 SNES Function norm 2.18715e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292234
#   1 SNES Function norm 1.56012e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 332, dt 6.458599173774354e-05
# t_rms = 0.5669803375423192, v_rms = 54.11907046302867, Nu = 2.4403049115349873
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00912644
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000135757
#   1 SNES Function norm 1.57694e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292234
#   1 SNES Function norm 1.56012e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 333, dt 6.458823137351831e-05
# t_rms = 0.5669804192811223, v_rms = 54.11888723435768, Nu = 2.440304547321879
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.0363774
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000360286
#   1 SNES Function norm 6.17482e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292234
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 334, dt 6.457521819211811e-05
# t_rms = 0.5669807269569119, v_rms = 54.11875215194497, Nu = 2.4403239464684163
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.108299
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000471156
#   1 SNES Function norm 7.97774e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292233
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 335, dt 6.45636386138121e-05
# t_rms = 0.5669807305177021, v_rms = 54.118578228543925, Nu = 2.4403082017263613
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.0344385
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000287216
#   1 SNES Function norm 4.79374e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292233
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 336, dt 6.461576495324306e-05
# t_rms = 0.566980704615768, v_rms = 54.115116175215626, Nu = 2.4403007720996284
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00234998
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000223878
#   1 SNES Function norm 3.60644e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292233
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 337, dt 6.458862588091613e-05
# t_rms = 0.5669807972263675, v_rms = 54.11909882028629, Nu = 2.4402961917848325
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.0176728
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000144822
#   1 SNES Function norm 2.56682e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292232
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 338, dt 6.458948099269469e-05
# t_rms = 0.5669807908224448, v_rms = 54.118025213193704, Nu = 2.440291071953382
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00897818
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000156128
#   1 SNES Function norm 2.43651e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292232
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 339, dt 6.459203753721427e-05
# t_rms = 0.5669808745500822, v_rms = 54.118029923071916, Nu = 2.4402861599769077
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00908101
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000150632
#   1 SNES Function norm 1.84297e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292232
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 340, dt 6.458905565597758e-05
# t_rms = 0.5669809702688134, v_rms = 54.11774733662655, Nu = 2.4402847076713234
# Saving checkpoint for time step:  340
# Saving mesh file
#   0 SNES Function norm 243.417
#   1 SNES Function norm 0.00915638
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000138707
#   1 SNES Function norm 1.65212e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292232
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 341, dt 6.458981731989903e-05
# t_rms = 0.5669810569581971, v_rms = 54.11755611000809, Nu = 2.4402838181618036
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.00180284
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000142374
#   1 SNES Function norm 1.59606e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292231
#   1 SNES Function norm 1.56011e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 342, dt 6.458940259262657e-05
# t_rms = 0.5669811504023161, v_rms = 54.1173861090221, Nu = 2.4402827200012984
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0220608
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000289144
#   1 SNES Function norm 5.492e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292231
#   1 SNES Function norm 1.5601e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 343, dt 6.460674327900857e-05
# t_rms = 0.5669812518126945, v_rms = 54.117260086568805, Nu = 2.440269239797117
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0103346
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000192223
#   1 SNES Function norm 3.68525e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292231
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 344, dt 6.460226930558059e-05
# t_rms = 0.5669813493956043, v_rms = 54.117379299182375, Nu = 2.4402644907056374
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.00893545
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000185965
#   1 SNES Function norm 2.65651e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029223
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 345, dt 6.45930690150794e-05
# t_rms = 0.5669814402846451, v_rms = 54.11706670183682, Nu = 2.4402579291400683
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0010245
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000156599
#   1 SNES Function norm 2.31934e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029223
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 346, dt 6.459348286572452e-05
# t_rms = 0.5669815223532724, v_rms = 54.11676367411717, Nu = 2.4402540181627743
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0334038
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000147117
#   1 SNES Function norm 2.77107e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029223
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 347, dt 6.460034588340095e-05
# t_rms = 0.5669814985936524, v_rms = 54.116590149499295, Nu = 2.440259363521832
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.000878906
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000171604
#   1 SNES Function norm 2.56071e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.029223
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 348, dt 6.459256561703638e-05
# t_rms = 0.5669815867859359, v_rms = 54.116724382217654, Nu = 2.4402542725077234
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.000393881
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.0001479
#   1 SNES Function norm 1.83499e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292229
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 349, dt 6.459259070998613e-05
# t_rms = 0.566981674398715, v_rms = 54.11636938944451, Nu = 2.440251214696271
#   0 SNES Function norm 243.418
#   1 SNES Function norm 0.0091072
# Nonlinear stokes_ solve converged due to CONVERGED_ITS iterations 1
#   0 SNES Function norm 0.000142728
#   1 SNES Function norm 1.76209e-09
# Nonlinear adv_diff_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
#   0 SNES Function norm 0.0292229
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1
# Timestep 350, dt 6.459086573974773e-05
# t_rms = 0.566981767437589, v_rms = 54.116201308250986, Nu = 2.44025119480648
# Saving checkpoint for time step:  350
# Saving mesh file
# Saving mesh file

# %%
        
plotFig(meshbox, t_soln, v_soln, "T", save_fname = None, with_arrows = False, cmap = "coolwarm")
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'18f2149c-23f3-4e21-94fd-bc7e347820c2': {'defs': …

# %%
if uw.mpi.rank == 0:
        import matplotlib.pyplot as plt

        # plot how Nu is evolving through time
        fig,ax = plt.subplots(dpi = 100)

        #ax.hlines(42.865, 0, 2000, linestyle = "--", linewidth = 0.5, color = "gray", label = r"Benchmark $v_{rms}$")
        ax.plot(np.arange((~np.isnan(NuVal)).sum()), 
                NuVal[~np.isnan(NuVal)], 
                color = "k", 
                label = str(res) + " x " + str(res))

        ax.legend()
        ax.set_xlabel("Time step")
        ax.set_ylabel(r"$Nu$", color = "k")

        # ax.set_xlim([0, 2000])
        # ax.set_ylim([0, 100])

# %%
# Calculate some benchmark values
if uw.mpi.rank == 0:
    print("RMS velocity at the final time step is {}.".format(v_rms()))
    print("Nusselt number at the final time step is {}.".format(Nu))
# Out:
# RMS velocity at the final time step is 54.11602101391714.
# Nusselt number at the final time step is 2.44025119480648.

# %% [markdown]
# ### Post-run analysis - Change to TALA values
#
# **Benchmark values**
# The loop above outputs $v_{rms}$ as a general statistic for the system. For further comparison, the benchmark values for the RMS velocity, $v_{rms}$, Nusselt number, $Nu$, and non-dimensional gradients at the cell corners, $q_1$ and $q_2$, are shown below for different Rayleigh numbers. All benchmark values shown below were determined in Blankenbach *et al.* 1989 by extroplation of numerical results.
#
# | $Ra$ | $v_{rms}$ | $Nu$ | $q_1$ | $q_2$ |
# | ------------- |:-------------:|:-----:|:-----:|:-----:|
# | 10$^4$ | 42.865 | 4.884 | 8.059 | 0.589 |
# | 10$^5$ | 193.215 | 10.535 | 19.079 | 0.723 |
# | 10$^6$ | 833.990 | 21.972 | 45.964 | 0.877 |

# %%
# some things to set-up before post-processing

# set expression for calculating sigma_zz
sigma_zz_fn = stokes.stress[1, 1]

dTdZ_calc.solve() # recalculate gradient of T along Z
# Out:
#   0 SNES Function norm 0.0292229
#   1 SNES Function norm 1.56009e-06
# Nonlinear SProj_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1

# %% [markdown]
# ### Calculate the $Nu$ value
# The Nusselt number is defined as:
#
# \begin{aligned}
# Nu  =   -h\frac{ \int_{0}^{l} \partial_{z}T(x, z = h) dx} {\int_{0}^{l} T(x, z = 0) dx}
# \end{aligned}

# %%
up_int = surface_integral(meshbox, dTdZ.sym[0], up_surface_defn_fn)
lw_int = surface_integral(meshbox, t_soln.sym[0], lw_surface_defn_fn)

Nu = -up_int/lw_int

if uw.mpi.rank == 0:
    print("Calculated value of Nu: {}".format(Nu))
# Out:
# Calculated value of Nu: 2.44025119480648

# %% [markdown]
# ### Calculate the non-dimensional gradients at the cell corners, $q_i$
# The non-dimensional temperature gradient at the cell corner, $q_i$, is defined as:
# \begin{aligned}
# q  =  \frac{-h}{\Delta T} \left( \frac{\partial T}{\partial z} \right)
# \end{aligned}
#
# Note that these values depend on the non-dimensional temperature gradient in the vertical direction, $\frac{\partial T}{\partial z}$.
# These gradients are evaluated at the following points:
#
# $q_1$ at $x=0$, $z=h$; $q_2$ at $x=l$, $z=h$;
#
# $q_3$ at $x=l$, $z=0$; $q_4$ at $x=0$, $z=0$.

# %%
# calculate q values which depend on the temperature gradient fields

# NOTE: for quadratic elements, may need to set boundary value (e.g. boxHeight) to 0.99999*value (e.g. 0.9999*boxHeight)
q1 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ.sym[0], np.array([[0., boxHeight]]))[0]
q2 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ.sym[0], np.array([[boxLength, boxHeight]]))[0]
q3 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ.sym[0], np.array([[boxLength, 0.]]))[0]
q4 = -(boxHeight/(tempMax - tempMin))*uw.function.evaluate(dTdZ.sym[0], np.array([[0., 0.]]))[0]

if uw.mpi.rank == 0:
    print('Rayleigh number = {0:.1e}'.format(Ra))
    print('q1 = {0:.3f}; q2 = {1:.3f}'.format(q1, q2))
    print('q3 = {0:.3f}; q4 = {1:.3f}'.format(q3, q4))
# Out:
# Rayleigh number = 1.0e+04
# q1 = 3.607; q2 = 0.868
# q3 = 3.683; q4 = 0.561

# %% [markdown]
# ### Calculate the stress for comparison with benchmark value
#
# The stress field for whole box in dimensionless units (King 2009) is:
# \begin{equation}
# \tau_{ij} = \eta \frac{1}{2} \left[ \frac{\partial v_j}{\partial x_i} + \frac{\partial v_i}{\partial x_j}\right].
# \end{equation}
# For vertical normal stress it becomes:
# \begin{equation}
# \tau_{zz} = \eta \frac{1}{2} \left[ \frac{\partial v_z}{\partial z} + \frac{\partial v_z}{\partial z}\right] = \eta \frac{\partial v_z}{\partial z}.
# \end{equation}
# This is calculated below.

# %%
# projection object for the stress in the zz direction

stress_calc = uw.systems.Projection(meshbox, sigma_zz)
stress_calc.uw_function = sigma_zz_fn
stress_calc.smoothing = 1.0e-3
stress_calc.petsc_options.delValue("ksp_monitor")
stress_calc.solve()
# Out:
#   0 SNES Function norm 63.5735
#   1 SNES Function norm 0.00257642
# Nonlinear SProj_2_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 1

# %% [markdown]
# The vertical normal stress is dimensionalised as:
#
# $$
#     \sigma_{t} = \frac{\eta_0 \kappa}{\rho g h^2}\tau _{zz} \left( x, z=h\right)
# $$
#
# where all constants are defined below.
#
# Finally, we calculate the topography defined using $h = \sigma_{top} / (\rho g)$. The topography of the top boundary calculated in the left and right corners as given in Table 9 of Blankenbach et al 1989 are:
#
# | $Ra$          |    $\xi_1$  | $\xi_2$  |  $x$ ($\xi = 0$) |
# | ------------- |:-----------:|:--------:|:--------------:|
# | 10$^4$  | 2254.02   | -2903.23  | 0.539372          |
# | 10$^5$  | 1460.99   | -2004.20  | 0.529330          |
# | 10$^6$  | 931.96   | -1283.80  | 0.506490          |

# %%
# subtract the average value for the benchmark since the mean is set to zero 

mean_sigma_zz_top = -surface_integral(meshbox, 
                                     sigma_zz.sym[0], 
                                     up_surface_defn_fn)/boxLength

# %%
# Set parameters in SI units

grav = 10        # m.s^-2
height = 1.e6    # m 
rho  = 4.0e3     # g.m^-3
kappa  = 1.0e-6  # m^2.s^-1

eta0=1.e23

def calculate_topography(coord): # only coord has local scope

    sigma_zz_top = -uw.function.evaluate(sigma_zz.sym[0], coord) - mean_sigma_zz_top
    
    # dimensionalise 
    dim_sigma_zz_top  = ((eta0 * kappa) / (height**2)) * sigma_zz_top
    topography = dim_sigma_zz_top / (rho * grav)
    
    return topography

# %%
# topography at the top corners 
e1 = calculate_topography(np.array([[0, boxHeight]]))
e2 = calculate_topography(np.array([[boxLength, boxHeight]]))

# calculate the x-coordinate with zero stress
with meshbox.access():
    cond = meshbox.data[:, 1] == meshbox.data[:, 1].max()
    up_surface_coords = meshbox.data[cond]
    up_surface_coords[:, 1] = 0.999999*up_surface_coords[:, 1]

abs_topo = abs(calculate_topography(up_surface_coords))

min_abs_topo_coord = up_surface_coords[np.where(abs_topo == abs_topo.min())[0]].flatten()

if uw.mpi.rank == 0:
    print("Topography [x=0], [x=max] = {0:.2f}, {1:.2f}".format(e1[0], e2[0]))
    print("x where topo = 0 is at {0:.6f}".format(min_abs_topo_coord[0]))
# Out:
# Topography [x=0], [x=max] = 2322.78, -2693.72
# x where topo = 0 is at 0.500000
